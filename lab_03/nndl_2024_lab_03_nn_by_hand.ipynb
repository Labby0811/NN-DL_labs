# %% [markdown]
# # NEURAL NETWORKS AND DEEP LEARNING
#
# ---
# A.A. 2023/24 (6 CFU) - Dr. Jacopo Pegoraro, Dr. Daniele Mari, Dr. Riccardo Mazzieri
# ---
#
#
# ## Supplementary  material - Neural network manual implementation

# %%
import numpy as np
import matplotlib.pyplot as plt

# manual implementation: no torch required!

# %% [markdown]
# # Theoretical Background

# %% [markdown]
# ### Artificial Neuron

# %% [markdown]
# This is the structure of a single artificial neuron

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Fully connected feed-forward network

# %% [markdown]
# A neural network is composed by several artificial neurons, typically organized in layers and connected in different ways. One of the most common neural network is the **fully-connected feed-forward network**, where each neuron is connected to all the neurons of the previous layer. The first layer takes the feature vector as input, and the number of outputs is defined by the number of neurons in the last layer.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# All the linear computation of a single layer (without considering the activation function) can be simply expressed in a matrix form, as follows:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# When we include the activation function and we consider more than one layer (2 hidden layers in this example) we still have a quite simple expression for the entire network. $X$ is the input vector, $H_n$ are the linear activations, $Z_n$ are the non-linear activations, and $Y$ is the output.
#
# The computation of this equation is typically referred to as *forward-pass*.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Gradient Descent

# %% [markdown]
# When we use a neural network for a regression or classification problem, we compare the output the network with the actual values given by a training set.
#
# This comparison is quantified by a **loss function**. In this case we consider a Mean Square Error (MSE) function, analogously to the least square problem analyzed in the previous lab.
#
# The main goal is to find a set of parameters $W$ that minimizes the loss function. The rationale behind the **gradient descent** algorithm is to slighlty update the values of the weights depending on their gradient wrt the loss function. The update is repeated until we reach a stopping criteria, e.g. the training loss is not decreasing anymore, or the loss function evaluated on the validation set (**validation loss**) starts to increase (**overfitting**).
#
# It is clear that the main point here is to evaluate the gradient of the weights wrt the loss function. Starting from the output layer, and thanks to the **chain rule**, we can easily leverage previously evaluated gradients to simplify the computation (**back-propagation**).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# If you apply the chain rule, as you cas see below, most of the computation is shared among the layers.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Doing the math, you have the following gradients. We define the variables $D_n$ to have a reference for the code below.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Activation Functions

# %% [markdown]
# There are several non-linear activation function that can be used, each of which has specific properties and tackles specific issues. Here some examples:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Generate training and test data

# %% [markdown]
# Let's define the same model used for the OLS implementation of the previous labs.

# %%
# Set random seed
np.random.seed(3)

### Define a simple quadratic model
# y = a + b * x + c * x^2
# a = -1.45, b = 1.12, c = 2.3

def poly_model(x, beta, noise_std=0):
    """
    INPUT
        x: x vector
        beta: polynomial parameters
        noise_std: enable noisy sampling (gaussian noise, zero mean, noise_std std)
    """
    pol_order = len(beta)
    x_matrix = np.array([x**i for i in range(pol_order)]).transpose()
    y = np.matmul(x_matrix, beta)
    noise = np.random.randn(len(y)) * noise_std
    return y + noise

### True parameter values
beta_true = [-1.45, 1.12, 2.3]

### Set random seed
np.random.seed(3)

### Generate 10 train points
num_train_points = 10
x_train = np.random.rand(num_train_points)
y_train = poly_model(x_train, beta_true, noise_std=0.2)

### Generate 10 test points
num_test_points = 10
x_test = np.random.rand(num_test_points)
y_test = poly_model(x_test, beta_true, noise_std=0.2)

### Plot
plt.figure(figsize=(12,8))
x_highres = np.linspace(0,1,1000)
plt.plot(x_highres, poly_model(x_highres, beta_true), color='b', ls='--', label='True data model')
plt.plot(x_train, y_train, color='r', ls='', marker='.', label='Train data points')
plt.plot(x_test, y_test, color='g', ls='', marker='.', label='Test data points')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Activation function

# %% [markdown]
# Let's define the activation function *act* and its dervivative *act_der*. We consider a **sigmoid** activation function, which is available in the *scipy* python package in the *scipy.special* module named as *expit*.
#
# Fortunately, the derivative of the sigmoid $\sigma(x)$ is quite simple:
#
# $$
# \sigma(x) = \frac{1}{1+e^{-x}}\\
# \frac{d\sigma}{dx} = \sigma(x) * (1 - \sigma(x))
# $$

# %%
# Define activation function
from scipy.special import expit
##################################
#PUT YOUR CODE HERE
act = expit
# 1st derivative
act_der = lambda x: act(x) * (1 - act(x))
##################################

# Plot activation function
x_plot = np.linspace(-5,5,1000)
y_act = act(x_plot)
y_act_der = act_der(x_plot)

plt.figure(figsize=(16,10))
plt.plot(x_plot, y_act, label='Sigmoid function')
plt.plot(x_plot, y_act_der, label='Sigmoid 1st derivative')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Network definition

# %% [markdown]
# Let's define the entire network using a class. We are implementing a fully connected feed-forward network with 2 hidden layers. The class has the following structure:
# ```
# class Network():
#
#     def __init__(self, Ni, Nh1, Nh2, No):
#         [...]
#
#     def forward(self, x, additional_out=False):
#         [...]
#
#     def update(self, x, label, lr):
#         [...]
#
#     def plot_weights(self):
#         [...]
#
# ```
#
#
# *   **\_\_init\_\_ method** - Here we initialize all the parameters (weights and biases) of the network. It requires the number of inputs ($N_i$) and outputs ($N_o$) and the number of neurons in the hidden layers ($N_h1$ and $N_h2$). The weights are initialized randomly, following the procedure proposed by Xavier et al. i.e. they are initialized with uniform distribution from $$\mathcal{U}(-0.5, 0.5)*\sqrt{\frac{12}{N_i + N_o}}$$
#  The biases are initialized to zero.
# *   **forward** - Evaluate the output of the network given an input $x$. If the *additional_out* parameter is True, it also outputs the activations of the secon hidden layer $Z_2$, for visualization.
# * **update** - Given a training sample (*x* and *label*), evaluate all the gradients and perform the update of the weigths with a learning rate *lr*.
# * **plot_weights** - Utility function to plot all the weights of the network.

# %%
###QUI HO CREATO QUESTO CODICE PER VERICARE SE I DUE METODI DI GENERAZIONE RANDOMICA SONO EFFETTIVAMENTE UGUALI###
Ni = 10
Nh1 = 128
Wh1 = np.random.uniform(-0.5, 0.5, (Ni,Nh1))
Wh2 =  np.random.rand(Nh1,Ni) -0.5

#Wh1 = Wh1.T
print(Wh1.shape)
print(Wh1)
print("\n")
print (Wh2.shape)
print(Wh2)

x1 = np.arange(Wh1.size)
y1 = Wh1.flatten()  # Appiattiamo la matrice per ottenere i valori come un array

# Punti di Wh2
x2 = np.arange(Wh2.size)
y2 = Wh2.flatten()  # Appiattiamo anche Wh2

# Creazione della figura
plt.figure(figsize=(10, 6))
plt.scatter(x1, y1, color='red', label='Wh1 (rossi)', alpha=0.5)
plt.scatter(x2, y2, color='blue', label='Wh2 (blu)', alpha=0.5)

# Aggiungi etichette e legenda
plt.xlabel('Indice del punto')
plt.ylabel('Valore')
plt.legend()
plt.title('Distribuzione dei punti di Wh1 e Wh2')

# Mostra la figura
plt.show()
# Out:
# (10, 128)
# [[ 3.71334312e-01 -4.94248382e-01 -3.47981111e-01 ... -2.82672001e-01
#   -3.22625591e-01 -4.86507462e-02]
#  [ 2.42626617e-04 -4.14346629e-01  2.34111148e-01 ... -1.32758791e-01
#    7.47575066e-02  1.87028221e-01]
#  [-6.48238145e-02 -2.42265135e-01  2.15976723e-02 ... -2.66315224e-02
#   -3.56523394e-01  4.10632203e-01]
#  ...
#  [-1.32268468e-01 -5.16631166e-03 -3.78009034e-01 ...  2.10386124e-01
#   -2.81717216e-02  2.44732822e-01]
#  [ 3.66453707e-01 -3.84347080e-02  3.29105150e-01 ...  8.16006617e-02
#   -3.76366590e-01 -1.25167083e-01]
#  [ 3.26545419e-02  1.59871591e-01 -9.59977549e-02 ... -7.12300559e-02
#    3.69576431e-01 -2.57796340e-01]]
#
#
# (128, 10)
# [[-0.23964681 -0.18849137 -0.09746739 ... -0.32147726 -0.28403456
#   -0.19460409]
#  [-0.07396849 -0.12018704  0.04827965 ...  0.48257651 -0.47629356
#    0.34396971]
#  [-0.34318925  0.04592561  0.27235666 ... -0.12626653  0.4627048
#    0.25935604]
#  ...
#  [-0.45768785  0.26940729 -0.07400359 ... -0.03967304  0.3977747
#    0.16331446]
#  [-0.46331039  0.26190647  0.31582398 ...  0.22284257 -0.41514184
#   -0.01322581]
#  [ 0.48490147  0.15947906  0.293193   ... -0.15226461 -0.40957386
#    0.26325346]]

# %%
class Network():

    def __init__(self, Ni, Nh1, Nh2, No):

        ### WEIGHT INITIALIZATION (Xavier)
        # Initialize hidden weights and biases (layer 1)
        Wh1 = (np.random.rand(Nh1, Ni) -0.5) * np.sqrt(12 / (Ni + Nh1))  #####L'ORDINE è INVERTITO PERCHè LA MATRICE è PREMOLTIPLICATA
        Bh1 = np.zeros([Nh1, 1])
        self.WBh1 = np.concatenate([Wh1, Bh1], 1) # Weight matrix including biases
        # Initialize hidden weights and biases (layer 2)
        Wh2 = (np.random.rand(Nh2, Nh1) -0.5) * np.sqrt(12 / (Nh2 + Nh1))
        Bh2 = np.zeros([Nh2, 1])
        self.WBh2 = np.concatenate([Wh2, Bh2], 1) # Weight matrix including biases
        # Initialize output weights and biases
        Wo = (np.random.rand(No, Nh2) -0.5) * np.sqrt(12 / (No + Nh2))
        Bo = np.zeros([No, 1])
        self.WBo = np.concatenate([Wo, Bo], 1) # Weight matrix including biases

        ### ACTIVATION FUNCTION
        self.act = expit
        self.act_der = lambda x: act(x) * (1 - act(x))

    def forward(self, x, additional_out=False):

        # Convert to numpy array
        x = np.array(x)

        ### Hidden layer 1
        # Add bias term (remember homogeneous coordinates i.e. append a 1 at the end)
        X = np.append(x, 1)
        # Forward pass (linear)
        H1 = self.WBh1 @ X   ###np.mathmul(self.WBh1, X)
        # Activation function
        Z1 = self.act(H1)

        ### Hidden layer 2
        # Add bias term (remember homogeneous coordinates i.e. append a 1 at the end)
        Z1 = np.append(Z1, 1)
        # Forward pass (linear)
        H2 = self.WBh2 @ Z1
        # Activation function
        Z2 = self.act(H2)

        ### Output layer
        # Add bias term (remember homogeneous coordinates i.e. append a 1 at the end)
        Z2 = np.append(Z2, 1)
        # Forward pass (linear)
        Y = self.WBo @ Z2
        # NO activation function

        if additional_out:
            return Y.squeeze(), Z2

        return Y.squeeze()

    def update(self, x, label, lr):

        # Convert to numpy array
        X = np.array(x)

       ### Hidden layer 1
        # Add bias term (remember homogeneous coordinates i.e. append a 1 at the end)
        X = np.append(X, 1)
        # Forward pass (linear)
        H1 = self.WBh1 @ X   ###np.mathmul(self.WBh1, X)
        # Activation function
        Z1 = self.act(H1)

        ### Hidden layer 2
        # Add bias term (remember homogeneous coordinates i.e. append a 1 at the end)
        Z1 = np.append(Z1, 1)
        # Forward pass (linear)
        H2 = self.WBh2 @ Z1
        # Activation function
        Z2 = self.act(H2)

        ### Output layer
        # Add bias term (remember homogeneous coordinates i.e. append a 1 at the end)
        Z2 = np.append(Z2, 1)
        # Forward pass (linear)
        Y = self.WBo @ Z2
        # NO activation function

        # Evaluate the derivative terms (remember that the biases are concatenated with the weights)
        D1 = Y - label
        D2 = Z2
        D3 = self.WBo[:, :-1]
        D4 = self.act_der(H2)
        D5 = Z1
        D6 = self.WBh2[:, :-1]
        D7 = self.act_der(H1)
        D8 = X

        # Layer Error (these are needed later to compte dWBo, dWBh2, dWBh1 as dWBo=Eo*D2, dWB2=Eh2*D5, dWB1=Eh1*D8)
        Eo = D1
        Eh2 = np.matmul(Eo, D3) * D4   ##### !!!!! QUA MOLTIPLICO ELEMENT WISE PERCHè D4 è UNA DERIVATA
        Eh1 = np.matmul(Eh2, D6) * D7


        # Derivative for weight matrices
        dWBo = np.matmul(Eo.reshape(-1, 1), D2.reshape(1, -1))
        dWBh2 = np.matmul(Eh2.reshape(-1, 1), D5.reshape(1, -1))
        dWBh1 = np.matmul(Eh1.reshape(-1, 1), D8.reshape(1, -1))

        # Update the weights
        self.WBh1 -= lr * dWBh1
        self.WBh2 -= lr * dWBh2
        self.WBo -= lr * dWBo

        # Evaluate loss function
        loss = D1**2 /2

        return loss

    def plot_weights(self):

        fig, axs = plt.subplots(3, 1, figsize=(12,6))
        axs[0].hist(self.WBh1.flatten(), 20)
        axs[1].hist(self.WBh2.flatten(), 50)
        axs[2].hist(self.WBo.flatten(), 20)
        plt.legend()
        plt.grid()
        plt.show()

# %% [markdown]
# Now we can instantiate the actual object.

# %%
### PARAMETERS
Ni = 1 # Number of inputs
Nh1 = 128 # Number of hidden neurons (layer 1)
Nh2 = 512 # Number of hidden neurons (layer 2)
No = 1 # Number of outputs

### Initialize network
net = Network(Ni, Nh1, Nh2, No)

# Access the class members
print('1st hidden layer weigth matrix shape:', net.WBh1.shape)
print('2nd hidden layer weigth matrix shape:', net.WBh2.shape)
print('Output layer weigth matrix shape:', net.WBo.shape)

# Plot weights
plt.close('all')
net.plot_weights()
# Out:
# 1st hidden layer weigth matrix shape: (128, 2)
# 2nd hidden layer weigth matrix shape: (512, 129)
# Output layer weigth matrix shape: (1, 513)
# C:\Users\giuse\AppData\Local\Temp\ipykernel_15656\3783862196.py:121: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# Let's check what is the output of the network just initialized, without having performed any training step.

# %%
### FORWARD PASS (before training)
# Define the x vector
x_highres = np.linspace(0, 1, 1000)

# Evaluate the output for each input (this can be done as a batch, but for now let's do 1 input at a time)
initial_net_output = []
for x in x_highres:
    net_out = net.forward(x)
    initial_net_output.append(net_out)
initial_net_output = np.array(initial_net_output)

# Or in just 1 line of pythonic code!!
initial_net_output = np.array([net.forward(x) for x in x_highres])

### Plot
plt.close('all')
plt.figure(figsize=(12,8))
x_highres = np.linspace(0,1,1000)
plt.plot(x_highres, poly_model(x_highres, beta_true), color='b', ls='--', label='True data model')
plt.plot(x_train, y_train, color='r', ls='', marker='.', label='Train data points')
plt.plot(x_highres, initial_net_output, color='g', ls='--', label='Network output (random weights)')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# As you can see, the output is just a random value. Let's train this network.

# %% [markdown]
# # Network training

# %% [markdown]
# Here, a **learning rate decay** can be optionally enabled, which decrease the learning rate from *lr* to *lr_final* during the training.

# %%
#%% TRAINING
num_epochs = 5000
lr = 1e-2
en_decay = False
lr_final = 1e-5
lr_decay = (lr_final / lr)**(1 / num_epochs)

train_loss_log = []
test_loss_log = []
for num_ep in range(num_epochs):
    # Learning rate decay
    if en_decay:
        lr *= lr_decay
    # Train single epoch (sample by sample, no batch for now)
    train_loss_vec = [net.update(x, y, lr) for x, y in zip(x_train, y_train)]
    avg_train_loss = np.mean(train_loss_vec)
    # Test network
    y_test_est = np.array([net.forward(x) for x in x_test])
    avg_test_loss = np.mean((y_test_est - y_test)**2/2)
    # Log
    train_loss_log.append(avg_train_loss)
    test_loss_log.append(avg_test_loss)
    print('Epoch %d - lr: %.5f - Train loss: %.5f - Test loss: %.5f' % (num_ep + 1, lr, avg_train_loss, avg_test_loss))
# Out:
# Epoch 1 - lr: 0.01000 - Train loss: 0.95814 - Test loss: 0.40070
# Epoch 2 - lr: 0.01000 - Train loss: 0.91271 - Test loss: 0.40170
# Epoch 3 - lr: 0.01000 - Train loss: 0.91012 - Test loss: 0.40271
# Epoch 4 - lr: 0.01000 - Train loss: 0.90763 - Test loss: 0.40373
# Epoch 5 - lr: 0.01000 - Train loss: 0.90523 - Test loss: 0.40476
# Epoch 6 - lr: 0.01000 - Train loss: 0.90291 - Test loss: 0.40581
# Epoch 7 - lr: 0.01000 - Train loss: 0.90068 - Test loss: 0.40686
# Epoch 8 - lr: 0.01000 - Train loss: 0.89853 - Test loss: 0.40793
# Epoch 9 - lr: 0.01000 - Train loss: 0.89645 - Test loss: 0.40900
# Epoch 10 - lr: 0.01000 - Train loss: 0.89445 - Test loss: 0.41007
# Epoch 11 - lr: 0.01000 - Train loss: 0.89251 - Test loss: 0.41116
# Epoch 12 - lr: 0.01000 - Train loss: 0.89065 - Test loss: 0.41224
# Epoch 13 - lr: 0.01000 - Train loss: 0.88884 - Test loss: 0.41333
# Epoch 14 - lr: 0.01000 - Train loss: 0.88710 - Test loss: 0.41443
# Epoch 15 - lr: 0.01000 - Train loss: 0.88542 - Test loss: 0.41552
# Epoch 16 - lr: 0.01000 - Train loss: 0.88379 - Test loss: 0.41662
# Epoch 17 - lr: 0.01000 - Train loss: 0.88222 - Test loss: 0.41772
# Epoch 18 - lr: 0.01000 - Train loss: 0.88070 - Test loss: 0.41882
# Epoch 19 - lr: 0.01000 - Train loss: 0.87923 - Test loss: 0.41992
# Epoch 20 - lr: 0.01000 - Train loss: 0.87781 - Test loss: 0.42102
# Epoch 21 - lr: 0.01000 - Train loss: 0.87643 - Test loss: 0.42212
# Epoch 22 - lr: 0.01000 - Train loss: 0.87510 - Test loss: 0.42322
# Epoch 23 - lr: 0.01000 - Train loss: 0.87381 - Test loss: 0.42432
# Epoch 24 - lr: 0.01000 - Train loss: 0.87256 - Test loss: 0.42542
# Epoch 25 - lr: 0.01000 - Train loss: 0.87136 - Test loss: 0.42651
# Epoch 26 - lr: 0.01000 - Train loss: 0.87019 - Test loss: 0.42761
# Epoch 27 - lr: 0.01000 - Train loss: 0.86905 - Test loss: 0.42870
# Epoch 28 - lr: 0.01000 - Train loss: 0.86796 - Test loss: 0.42979
# Epoch 29 - lr: 0.01000 - Train loss: 0.86689 - Test loss: 0.43088
# Epoch 30 - lr: 0.01000 - Train loss: 0.86586 - Test loss: 0.43197
# Epoch 31 - lr: 0.01000 - Train loss: 0.86486 - Test loss: 0.43305
# Epoch 32 - lr: 0.01000 - Train loss: 0.86389 - Test loss: 0.43414
# Epoch 33 - lr: 0.01000 - Train loss: 0.86295 - Test loss: 0.43522
# Epoch 34 - lr: 0.01000 - Train loss: 0.86204 - Test loss: 0.43629
# Epoch 35 - lr: 0.01000 - Train loss: 0.86115 - Test loss: 0.43737
# Epoch 36 - lr: 0.01000 - Train loss: 0.86030 - Test loss: 0.43844
# Epoch 37 - lr: 0.01000 - Train loss: 0.85946 - Test loss: 0.43951
# Epoch 38 - lr: 0.01000 - Train loss: 0.85865 - Test loss: 0.44058
# Epoch 39 - lr: 0.01000 - Train loss: 0.85787 - Test loss: 0.44164
# Epoch 40 - lr: 0.01000 - Train loss: 0.85711 - Test loss: 0.44271
# Epoch 41 - lr: 0.01000 - Train loss: 0.85637 - Test loss: 0.44377
# Epoch 42 - lr: 0.01000 - Train loss: 0.85565 - Test loss: 0.44482
# Epoch 43 - lr: 0.01000 - Train loss: 0.85495 - Test loss: 0.44588
# Epoch 44 - lr: 0.01000 - Train loss: 0.85427 - Test loss: 0.44693
# Epoch 45 - lr: 0.01000 - Train loss: 0.85361 - Test loss: 0.44798
# Epoch 46 - lr: 0.01000 - Train loss: 0.85297 - Test loss: 0.44903
# Epoch 47 - lr: 0.01000 - Train loss: 0.85234 - Test loss: 0.45007
# Epoch 48 - lr: 0.01000 - Train loss: 0.85173 - Test loss: 0.45111
# Epoch 49 - lr: 0.01000 - Train loss: 0.85114 - Test loss: 0.45215
# Epoch 50 - lr: 0.01000 - Train loss: 0.85057 - Test loss: 0.45319
# Epoch 51 - lr: 0.01000 - Train loss: 0.85001 - Test loss: 0.45423
# Epoch 52 - lr: 0.01000 - Train loss: 0.84946 - Test loss: 0.45526
# Epoch 53 - lr: 0.01000 - Train loss: 0.84893 - Test loss: 0.45629
# Epoch 54 - lr: 0.01000 - Train loss: 0.84842 - Test loss: 0.45732
# Epoch 55 - lr: 0.01000 - Train loss: 0.84791 - Test loss: 0.45834
# Epoch 56 - lr: 0.01000 - Train loss: 0.84742 - Test loss: 0.45937
# Epoch 57 - lr: 0.01000 - Train loss: 0.84695 - Test loss: 0.46039
# Epoch 58 - lr: 0.01000 - Train loss: 0.84648 - Test loss: 0.46141
# Epoch 59 - lr: 0.01000 - Train loss: 0.84603 - Test loss: 0.46243
# Epoch 60 - lr: 0.01000 - Train loss: 0.84558 - Test loss: 0.46344
# Epoch 61 - lr: 0.01000 - Train loss: 0.84515 - Test loss: 0.46445
# Epoch 62 - lr: 0.01000 - Train loss: 0.84473 - Test loss: 0.46547
# Epoch 63 - lr: 0.01000 - Train loss: 0.84432 - Test loss: 0.46648
# Epoch 64 - lr: 0.01000 - Train loss: 0.84391 - Test loss: 0.46748
# Epoch 65 - lr: 0.01000 - Train loss: 0.84352 - Test loss: 0.46849
# Epoch 66 - lr: 0.01000 - Train loss: 0.84314 - Test loss: 0.46949
# Epoch 67 - lr: 0.01000 - Train loss: 0.84276 - Test loss: 0.47049
# Epoch 68 - lr: 0.01000 - Train loss: 0.84240 - Test loss: 0.47149
# Epoch 69 - lr: 0.01000 - Train loss: 0.84204 - Test loss: 0.47249
# Epoch 70 - lr: 0.01000 - Train loss: 0.84169 - Test loss: 0.47349
# Epoch 71 - lr: 0.01000 - Train loss: 0.84134 - Test loss: 0.47448
# Epoch 72 - lr: 0.01000 - Train loss: 0.84101 - Test loss: 0.47547
# Epoch 73 - lr: 0.01000 - Train loss: 0.84068 - Test loss: 0.47646
# Epoch 74 - lr: 0.01000 - Train loss: 0.84036 - Test loss: 0.47745
# Epoch 75 - lr: 0.01000 - Train loss: 0.84004 - Test loss: 0.47843
# Epoch 76 - lr: 0.01000 - Train loss: 0.83973 - Test loss: 0.47942
# Epoch 77 - lr: 0.01000 - Train loss: 0.83943 - Test loss: 0.48040
# Epoch 78 - lr: 0.01000 - Train loss: 0.83913 - Test loss: 0.48138
# Epoch 79 - lr: 0.01000 - Train loss: 0.83884 - Test loss: 0.48235
# Epoch 80 - lr: 0.01000 - Train loss: 0.83855 - Test loss: 0.48333
# Epoch 81 - lr: 0.01000 - Train loss: 0.83827 - Test loss: 0.48430
# Epoch 82 - lr: 0.01000 - Train loss: 0.83800 - Test loss: 0.48527
# Epoch 83 - lr: 0.01000 - Train loss: 0.83773 - Test loss: 0.48624
# Epoch 84 - lr: 0.01000 - Train loss: 0.83746 - Test loss: 0.48721
# Epoch 85 - lr: 0.01000 - Train loss: 0.83720 - Test loss: 0.48817
# Epoch 86 - lr: 0.01000 - Train loss: 0.83694 - Test loss: 0.48913
# Epoch 87 - lr: 0.01000 - Train loss: 0.83669 - Test loss: 0.49009
# Epoch 88 - lr: 0.01000 - Train loss: 0.83644 - Test loss: 0.49105
# Epoch 89 - lr: 0.01000 - Train loss: 0.83619 - Test loss: 0.49200
# Epoch 90 - lr: 0.01000 - Train loss: 0.83595 - Test loss: 0.49296
# Epoch 91 - lr: 0.01000 - Train loss: 0.83571 - Test loss: 0.49391
# Epoch 92 - lr: 0.01000 - Train loss: 0.83547 - Test loss: 0.49485
# Epoch 93 - lr: 0.01000 - Train loss: 0.83524 - Test loss: 0.49580
# Epoch 94 - lr: 0.01000 - Train loss: 0.83501 - Test loss: 0.49674
# Epoch 95 - lr: 0.01000 - Train loss: 0.83479 - Test loss: 0.49767
# Epoch 96 - lr: 0.01000 - Train loss: 0.83456 - Test loss: 0.49861
# Epoch 97 - lr: 0.01000 - Train loss: 0.83434 - Test loss: 0.49954
# Epoch 98 - lr: 0.01000 - Train loss: 0.83413 - Test loss: 0.50047
# Epoch 99 - lr: 0.01000 - Train loss: 0.83391 - Test loss: 0.50140
# Epoch 100 - lr: 0.01000 - Train loss: 0.83370 - Test loss: 0.50232
# Epoch 101 - lr: 0.01000 - Train loss: 0.83349 - Test loss: 0.50324
# Epoch 102 - lr: 0.01000 - Train loss: 0.83328 - Test loss: 0.50415
# Epoch 103 - lr: 0.01000 - Train loss: 0.83307 - Test loss: 0.50506
# Epoch 104 - lr: 0.01000 - Train loss: 0.83287 - Test loss: 0.50597
# Epoch 105 - lr: 0.01000 - Train loss: 0.83267 - Test loss: 0.50688
# Epoch 106 - lr: 0.01000 - Train loss: 0.83247 - Test loss: 0.50778
# Epoch 107 - lr: 0.01000 - Train loss: 0.83227 - Test loss: 0.50868
# Epoch 108 - lr: 0.01000 - Train loss: 0.83207 - Test loss: 0.50957
# Epoch 109 - lr: 0.01000 - Train loss: 0.83187 - Test loss: 0.51046
# Epoch 110 - lr: 0.01000 - Train loss: 0.83168 - Test loss: 0.51135
# Epoch 111 - lr: 0.01000 - Train loss: 0.83149 - Test loss: 0.51223
# Epoch 112 - lr: 0.01000 - Train loss: 0.83129 - Test loss: 0.51310
# Epoch 113 - lr: 0.01000 - Train loss: 0.83110 - Test loss: 0.51398
# Epoch 114 - lr: 0.01000 - Train loss: 0.83092 - Test loss: 0.51485
# Epoch 115 - lr: 0.01000 - Train loss: 0.83073 - Test loss: 0.51571
# Epoch 116 - lr: 0.01000 - Train loss: 0.83054 - Test loss: 0.51657
# Epoch 117 - lr: 0.01000 - Train loss: 0.83035 - Test loss: 0.51742
# Epoch 118 - lr: 0.01000 - Train loss: 0.83017 - Test loss: 0.51827
# Epoch 119 - lr: 0.01000 - Train loss: 0.82998 - Test loss: 0.51912
# Epoch 120 - lr: 0.01000 - Train loss: 0.82980 - Test loss: 0.51996
# Epoch 121 - lr: 0.01000 - Train loss: 0.82962 - Test loss: 0.52079
# Epoch 122 - lr: 0.01000 - Train loss: 0.82944 - Test loss: 0.52162
# Epoch 123 - lr: 0.01000 - Train loss: 0.82926 - Test loss: 0.52244
# Epoch 124 - lr: 0.01000 - Train loss: 0.82907 - Test loss: 0.52326
# Epoch 125 - lr: 0.01000 - Train loss: 0.82889 - Test loss: 0.52408
# Epoch 126 - lr: 0.01000 - Train loss: 0.82871 - Test loss: 0.52488
# Epoch 127 - lr: 0.01000 - Train loss: 0.82853 - Test loss: 0.52569
# Epoch 128 - lr: 0.01000 - Train loss: 0.82836 - Test loss: 0.52648
# Epoch 129 - lr: 0.01000 - Train loss: 0.82818 - Test loss: 0.52727
# Epoch 130 - lr: 0.01000 - Train loss: 0.82800 - Test loss: 0.52806
# Epoch 131 - lr: 0.01000 - Train loss: 0.82782 - Test loss: 0.52884
# Epoch 132 - lr: 0.01000 - Train loss: 0.82764 - Test loss: 0.52961
# Epoch 133 - lr: 0.01000 - Train loss: 0.82747 - Test loss: 0.53037
# Epoch 134 - lr: 0.01000 - Train loss: 0.82729 - Test loss: 0.53113
# Epoch 135 - lr: 0.01000 - Train loss: 0.82711 - Test loss: 0.53189
# Epoch 136 - lr: 0.01000 - Train loss: 0.82693 - Test loss: 0.53264
# Epoch 137 - lr: 0.01000 - Train loss: 0.82676 - Test loss: 0.53338
# Epoch 138 - lr: 0.01000 - Train loss: 0.82658 - Test loss: 0.53411
# Epoch 139 - lr: 0.01000 - Train loss: 0.82640 - Test loss: 0.53484
# Epoch 140 - lr: 0.01000 - Train loss: 0.82623 - Test loss: 0.53556
# Epoch 141 - lr: 0.01000 - Train loss: 0.82605 - Test loss: 0.53627
# Epoch 142 - lr: 0.01000 - Train loss: 0.82587 - Test loss: 0.53698
# Epoch 143 - lr: 0.01000 - Train loss: 0.82570 - Test loss: 0.53768
# Epoch 144 - lr: 0.01000 - Train loss: 0.82552 - Test loss: 0.53837
# Epoch 145 - lr: 0.01000 - Train loss: 0.82534 - Test loss: 0.53906
# Epoch 146 - lr: 0.01000 - Train loss: 0.82516 - Test loss: 0.53973
# Epoch 147 - lr: 0.01000 - Train loss: 0.82499 - Test loss: 0.54040
# Epoch 148 - lr: 0.01000 - Train loss: 0.82481 - Test loss: 0.54107
# Epoch 149 - lr: 0.01000 - Train loss: 0.82463 - Test loss: 0.54172
# Epoch 150 - lr: 0.01000 - Train loss: 0.82445 - Test loss: 0.54237
# Epoch 151 - lr: 0.01000 - Train loss: 0.82427 - Test loss: 0.54301
# Epoch 152 - lr: 0.01000 - Train loss: 0.82410 - Test loss: 0.54364
# Epoch 153 - lr: 0.01000 - Train loss: 0.82392 - Test loss: 0.54427
# Epoch 154 - lr: 0.01000 - Train loss: 0.82374 - Test loss: 0.54489
# Epoch 155 - lr: 0.01000 - Train loss: 0.82356 - Test loss: 0.54550
# Epoch 156 - lr: 0.01000 - Train loss: 0.82338 - Test loss: 0.54610
# Epoch 157 - lr: 0.01000 - Train loss: 0.82320 - Test loss: 0.54669
# Epoch 158 - lr: 0.01000 - Train loss: 0.82302 - Test loss: 0.54728
# Epoch 159 - lr: 0.01000 - Train loss: 0.82284 - Test loss: 0.54785
# Epoch 160 - lr: 0.01000 - Train loss: 0.82266 - Test loss: 0.54842
# Epoch 161 - lr: 0.01000 - Train loss: 0.82247 - Test loss: 0.54898
# Epoch 162 - lr: 0.01000 - Train loss: 0.82229 - Test loss: 0.54954
# Epoch 163 - lr: 0.01000 - Train loss: 0.82211 - Test loss: 0.55008
# Epoch 164 - lr: 0.01000 - Train loss: 0.82193 - Test loss: 0.55062
# Epoch 165 - lr: 0.01000 - Train loss: 0.82174 - Test loss: 0.55114
# Epoch 166 - lr: 0.01000 - Train loss: 0.82156 - Test loss: 0.55166
# Epoch 167 - lr: 0.01000 - Train loss: 0.82138 - Test loss: 0.55217
# Epoch 168 - lr: 0.01000 - Train loss: 0.82119 - Test loss: 0.55268
# Epoch 169 - lr: 0.01000 - Train loss: 0.82101 - Test loss: 0.55317
# Epoch 170 - lr: 0.01000 - Train loss: 0.82082 - Test loss: 0.55365
# Epoch 171 - lr: 0.01000 - Train loss: 0.82064 - Test loss: 0.55413
# Epoch 172 - lr: 0.01000 - Train loss: 0.82045 - Test loss: 0.55460
# Epoch 173 - lr: 0.01000 - Train loss: 0.82026 - Test loss: 0.55506
# Epoch 174 - lr: 0.01000 - Train loss: 0.82008 - Test loss: 0.55551
# Epoch 175 - lr: 0.01000 - Train loss: 0.81989 - Test loss: 0.55595
# Epoch 176 - lr: 0.01000 - Train loss: 0.81970 - Test loss: 0.55638
# Epoch 177 - lr: 0.01000 - Train loss: 0.81951 - Test loss: 0.55681
# Epoch 178 - lr: 0.01000 - Train loss: 0.81932 - Test loss: 0.55722
# Epoch 179 - lr: 0.01000 - Train loss: 0.81913 - Test loss: 0.55763
# Epoch 180 - lr: 0.01000 - Train loss: 0.81894 - Test loss: 0.55802
# Epoch 181 - lr: 0.01000 - Train loss: 0.81875 - Test loss: 0.55841
# Epoch 182 - lr: 0.01000 - Train loss: 0.81856 - Test loss: 0.55879
# Epoch 183 - lr: 0.01000 - Train loss: 0.81837 - Test loss: 0.55916
# Epoch 184 - lr: 0.01000 - Train loss: 0.81818 - Test loss: 0.55953
# Epoch 185 - lr: 0.01000 - Train loss: 0.81799 - Test loss: 0.55988
# Epoch 186 - lr: 0.01000 - Train loss: 0.81780 - Test loss: 0.56022
# Epoch 187 - lr: 0.01000 - Train loss: 0.81760 - Test loss: 0.56056
# Epoch 188 - lr: 0.01000 - Train loss: 0.81741 - Test loss: 0.56088
# Epoch 189 - lr: 0.01000 - Train loss: 0.81721 - Test loss: 0.56120
# Epoch 190 - lr: 0.01000 - Train loss: 0.81702 - Test loss: 0.56151
# Epoch 191 - lr: 0.01000 - Train loss: 0.81682 - Test loss: 0.56181
# Epoch 192 - lr: 0.01000 - Train loss: 0.81663 - Test loss: 0.56210
# Epoch 193 - lr: 0.01000 - Train loss: 0.81643 - Test loss: 0.56238
# Epoch 194 - lr: 0.01000 - Train loss: 0.81623 - Test loss: 0.56265
# Epoch 195 - lr: 0.01000 - Train loss: 0.81604 - Test loss: 0.56292
# Epoch 196 - lr: 0.01000 - Train loss: 0.81584 - Test loss: 0.56317
# Epoch 197 - lr: 0.01000 - Train loss: 0.81564 - Test loss: 0.56342
# Epoch 198 - lr: 0.01000 - Train loss: 0.81544 - Test loss: 0.56366
# Epoch 199 - lr: 0.01000 - Train loss: 0.81524 - Test loss: 0.56388
# Epoch 200 - lr: 0.01000 - Train loss: 0.81504 - Test loss: 0.56410
# Epoch 201 - lr: 0.01000 - Train loss: 0.81484 - Test loss: 0.56431
# Epoch 202 - lr: 0.01000 - Train loss: 0.81464 - Test loss: 0.56452
# Epoch 203 - lr: 0.01000 - Train loss: 0.81444 - Test loss: 0.56471
# Epoch 204 - lr: 0.01000 - Train loss: 0.81424 - Test loss: 0.56489
# Epoch 205 - lr: 0.01000 - Train loss: 0.81404 - Test loss: 0.56507
# Epoch 206 - lr: 0.01000 - Train loss: 0.81383 - Test loss: 0.56524
# Epoch 207 - lr: 0.01000 - Train loss: 0.81363 - Test loss: 0.56540
# Epoch 208 - lr: 0.01000 - Train loss: 0.81343 - Test loss: 0.56555
# Epoch 209 - lr: 0.01000 - Train loss: 0.81322 - Test loss: 0.56569
# Epoch 210 - lr: 0.01000 - Train loss: 0.81302 - Test loss: 0.56582
# Epoch 211 - lr: 0.01000 - Train loss: 0.81281 - Test loss: 0.56594
# Epoch 212 - lr: 0.01000 - Train loss: 0.81261 - Test loss: 0.56606
# Epoch 213 - lr: 0.01000 - Train loss: 0.81240 - Test loss: 0.56617
# Epoch 214 - lr: 0.01000 - Train loss: 0.81219 - Test loss: 0.56626
# Epoch 215 - lr: 0.01000 - Train loss: 0.81199 - Test loss: 0.56636
# Epoch 216 - lr: 0.01000 - Train loss: 0.81178 - Test loss: 0.56644
# Epoch 217 - lr: 0.01000 - Train loss: 0.81157 - Test loss: 0.56651
# Epoch 218 - lr: 0.01000 - Train loss: 0.81136 - Test loss: 0.56658
# Epoch 219 - lr: 0.01000 - Train loss: 0.81115 - Test loss: 0.56663
# Epoch 220 - lr: 0.01000 - Train loss: 0.81094 - Test loss: 0.56668
# Epoch 221 - lr: 0.01000 - Train loss: 0.81073 - Test loss: 0.56672
# Epoch 222 - lr: 0.01000 - Train loss: 0.81052 - Test loss: 0.56675
# Epoch 223 - lr: 0.01000 - Train loss: 0.81031 - Test loss: 0.56678
# Epoch 224 - lr: 0.01000 - Train loss: 0.81010 - Test loss: 0.56680
# Epoch 225 - lr: 0.01000 - Train loss: 0.80989 - Test loss: 0.56680
# Epoch 226 - lr: 0.01000 - Train loss: 0.80967 - Test loss: 0.56680
# Epoch 227 - lr: 0.01000 - Train loss: 0.80946 - Test loss: 0.56680
# Epoch 228 - lr: 0.01000 - Train loss: 0.80925 - Test loss: 0.56678
# Epoch 229 - lr: 0.01000 - Train loss: 0.80903 - Test loss: 0.56676
# Epoch 230 - lr: 0.01000 - Train loss: 0.80882 - Test loss: 0.56673
# Epoch 231 - lr: 0.01000 - Train loss: 0.80860 - Test loss: 0.56669
# Epoch 232 - lr: 0.01000 - Train loss: 0.80839 - Test loss: 0.56664
# Epoch 233 - lr: 0.01000 - Train loss: 0.80817 - Test loss: 0.56659
# Epoch 234 - lr: 0.01000 - Train loss: 0.80796 - Test loss: 0.56653
# Epoch 235 - lr: 0.01000 - Train loss: 0.80774 - Test loss: 0.56646
# Epoch 236 - lr: 0.01000 - Train loss: 0.80752 - Test loss: 0.56639
# Epoch 237 - lr: 0.01000 - Train loss: 0.80730 - Test loss: 0.56630
# Epoch 238 - lr: 0.01000 - Train loss: 0.80709 - Test loss: 0.56621
# Epoch 239 - lr: 0.01000 - Train loss: 0.80687 - Test loss: 0.56611
# Epoch 240 - lr: 0.01000 - Train loss: 0.80665 - Test loss: 0.56601
# Epoch 241 - lr: 0.01000 - Train loss: 0.80643 - Test loss: 0.56590
# Epoch 242 - lr: 0.01000 - Train loss: 0.80621 - Test loss: 0.56578
# Epoch 243 - lr: 0.01000 - Train loss: 0.80599 - Test loss: 0.56565
# Epoch 244 - lr: 0.01000 - Train loss: 0.80577 - Test loss: 0.56552
# Epoch 245 - lr: 0.01000 - Train loss: 0.80555 - Test loss: 0.56538
# Epoch 246 - lr: 0.01000 - Train loss: 0.80532 - Test loss: 0.56523
# Epoch 247 - lr: 0.01000 - Train loss: 0.80510 - Test loss: 0.56508
# Epoch 248 - lr: 0.01000 - Train loss: 0.80488 - Test loss: 0.56492
# Epoch 249 - lr: 0.01000 - Train loss: 0.80466 - Test loss: 0.56475
# Epoch 250 - lr: 0.01000 - Train loss: 0.80443 - Test loss: 0.56458
# Epoch 251 - lr: 0.01000 - Train loss: 0.80421 - Test loss: 0.56440
# Epoch 252 - lr: 0.01000 - Train loss: 0.80398 - Test loss: 0.56422
# Epoch 253 - lr: 0.01000 - Train loss: 0.80376 - Test loss: 0.56402
# Epoch 254 - lr: 0.01000 - Train loss: 0.80353 - Test loss: 0.56382
# Epoch 255 - lr: 0.01000 - Train loss: 0.80331 - Test loss: 0.56362
# Epoch 256 - lr: 0.01000 - Train loss: 0.80308 - Test loss: 0.56341
# Epoch 257 - lr: 0.01000 - Train loss: 0.80286 - Test loss: 0.56319
# Epoch 258 - lr: 0.01000 - Train loss: 0.80263 - Test loss: 0.56297
# Epoch 259 - lr: 0.01000 - Train loss: 0.80240 - Test loss: 0.56274
# Epoch 260 - lr: 0.01000 - Train loss: 0.80217 - Test loss: 0.56250
# Epoch 261 - lr: 0.01000 - Train loss: 0.80194 - Test loss: 0.56226
# Epoch 262 - lr: 0.01000 - Train loss: 0.80171 - Test loss: 0.56202
# Epoch 263 - lr: 0.01000 - Train loss: 0.80149 - Test loss: 0.56176
# Epoch 264 - lr: 0.01000 - Train loss: 0.80126 - Test loss: 0.56151
# Epoch 265 - lr: 0.01000 - Train loss: 0.80103 - Test loss: 0.56124
# Epoch 266 - lr: 0.01000 - Train loss: 0.80079 - Test loss: 0.56097
# Epoch 267 - lr: 0.01000 - Train loss: 0.80056 - Test loss: 0.56070
# Epoch 268 - lr: 0.01000 - Train loss: 0.80033 - Test loss: 0.56042
# Epoch 269 - lr: 0.01000 - Train loss: 0.80010 - Test loss: 0.56013
# Epoch 270 - lr: 0.01000 - Train loss: 0.79987 - Test loss: 0.55984
# Epoch 271 - lr: 0.01000 - Train loss: 0.79963 - Test loss: 0.55955
# Epoch 272 - lr: 0.01000 - Train loss: 0.79940 - Test loss: 0.55924
# Epoch 273 - lr: 0.01000 - Train loss: 0.79917 - Test loss: 0.55894
# Epoch 274 - lr: 0.01000 - Train loss: 0.79893 - Test loss: 0.55863
# Epoch 275 - lr: 0.01000 - Train loss: 0.79870 - Test loss: 0.55831
# Epoch 276 - lr: 0.01000 - Train loss: 0.79846 - Test loss: 0.55799
# Epoch 277 - lr: 0.01000 - Train loss: 0.79823 - Test loss: 0.55767
# Epoch 278 - lr: 0.01000 - Train loss: 0.79799 - Test loss: 0.55733
# Epoch 279 - lr: 0.01000 - Train loss: 0.79775 - Test loss: 0.55700
# Epoch 280 - lr: 0.01000 - Train loss: 0.79752 - Test loss: 0.55666
# Epoch 281 - lr: 0.01000 - Train loss: 0.79728 - Test loss: 0.55632
# Epoch 282 - lr: 0.01000 - Train loss: 0.79704 - Test loss: 0.55597
# Epoch 283 - lr: 0.01000 - Train loss: 0.79680 - Test loss: 0.55561
# Epoch 284 - lr: 0.01000 - Train loss: 0.79657 - Test loss: 0.55526
# Epoch 285 - lr: 0.01000 - Train loss: 0.79633 - Test loss: 0.55490
# Epoch 286 - lr: 0.01000 - Train loss: 0.79609 - Test loss: 0.55453
# Epoch 287 - lr: 0.01000 - Train loss: 0.79585 - Test loss: 0.55416
# Epoch 288 - lr: 0.01000 - Train loss: 0.79561 - Test loss: 0.55379
# Epoch 289 - lr: 0.01000 - Train loss: 0.79536 - Test loss: 0.55341
# Epoch 290 - lr: 0.01000 - Train loss: 0.79512 - Test loss: 0.55303
# Epoch 291 - lr: 0.01000 - Train loss: 0.79488 - Test loss: 0.55264
# Epoch 292 - lr: 0.01000 - Train loss: 0.79464 - Test loss: 0.55225
# Epoch 293 - lr: 0.01000 - Train loss: 0.79440 - Test loss: 0.55186
# Epoch 294 - lr: 0.01000 - Train loss: 0.79415 - Test loss: 0.55146
# Epoch 295 - lr: 0.01000 - Train loss: 0.79391 - Test loss: 0.55106
# Epoch 296 - lr: 0.01000 - Train loss: 0.79367 - Test loss: 0.55065
# Epoch 297 - lr: 0.01000 - Train loss: 0.79342 - Test loss: 0.55024
# Epoch 298 - lr: 0.01000 - Train loss: 0.79318 - Test loss: 0.54983
# Epoch 299 - lr: 0.01000 - Train loss: 0.79293 - Test loss: 0.54942
# Epoch 300 - lr: 0.01000 - Train loss: 0.79268 - Test loss: 0.54900
# Epoch 301 - lr: 0.01000 - Train loss: 0.79244 - Test loss: 0.54858
# Epoch 302 - lr: 0.01000 - Train loss: 0.79219 - Test loss: 0.54815
# Epoch 303 - lr: 0.01000 - Train loss: 0.79194 - Test loss: 0.54772
# Epoch 304 - lr: 0.01000 - Train loss: 0.79170 - Test loss: 0.54729
# Epoch 305 - lr: 0.01000 - Train loss: 0.79145 - Test loss: 0.54686
# Epoch 306 - lr: 0.01000 - Train loss: 0.79120 - Test loss: 0.54642
# Epoch 307 - lr: 0.01000 - Train loss: 0.79095 - Test loss: 0.54598
# Epoch 308 - lr: 0.01000 - Train loss: 0.79070 - Test loss: 0.54554
# Epoch 309 - lr: 0.01000 - Train loss: 0.79045 - Test loss: 0.54509
# Epoch 310 - lr: 0.01000 - Train loss: 0.79020 - Test loss: 0.54464
# Epoch 311 - lr: 0.01000 - Train loss: 0.78995 - Test loss: 0.54419
# Epoch 312 - lr: 0.01000 - Train loss: 0.78970 - Test loss: 0.54374
# Epoch 313 - lr: 0.01000 - Train loss: 0.78944 - Test loss: 0.54328
# Epoch 314 - lr: 0.01000 - Train loss: 0.78919 - Test loss: 0.54282
# Epoch 315 - lr: 0.01000 - Train loss: 0.78894 - Test loss: 0.54236
# Epoch 316 - lr: 0.01000 - Train loss: 0.78869 - Test loss: 0.54189
# Epoch 317 - lr: 0.01000 - Train loss: 0.78843 - Test loss: 0.54143
# Epoch 318 - lr: 0.01000 - Train loss: 0.78818 - Test loss: 0.54096
# Epoch 319 - lr: 0.01000 - Train loss: 0.78792 - Test loss: 0.54049
# Epoch 320 - lr: 0.01000 - Train loss: 0.78767 - Test loss: 0.54001
# Epoch 321 - lr: 0.01000 - Train loss: 0.78741 - Test loss: 0.53954
# Epoch 322 - lr: 0.01000 - Train loss: 0.78715 - Test loss: 0.53906
# Epoch 323 - lr: 0.01000 - Train loss: 0.78690 - Test loss: 0.53858
# Epoch 324 - lr: 0.01000 - Train loss: 0.78664 - Test loss: 0.53809
# Epoch 325 - lr: 0.01000 - Train loss: 0.78638 - Test loss: 0.53761
# Epoch 326 - lr: 0.01000 - Train loss: 0.78612 - Test loss: 0.53712
# Epoch 327 - lr: 0.01000 - Train loss: 0.78586 - Test loss: 0.53664
# Epoch 328 - lr: 0.01000 - Train loss: 0.78561 - Test loss: 0.53615
# Epoch 329 - lr: 0.01000 - Train loss: 0.78535 - Test loss: 0.53565
# Epoch 330 - lr: 0.01000 - Train loss: 0.78509 - Test loss: 0.53516
# Epoch 331 - lr: 0.01000 - Train loss: 0.78482 - Test loss: 0.53466
# Epoch 332 - lr: 0.01000 - Train loss: 0.78456 - Test loss: 0.53417
# Epoch 333 - lr: 0.01000 - Train loss: 0.78430 - Test loss: 0.53367
# Epoch 334 - lr: 0.01000 - Train loss: 0.78404 - Test loss: 0.53317
# Epoch 335 - lr: 0.01000 - Train loss: 0.78378 - Test loss: 0.53267
# Epoch 336 - lr: 0.01000 - Train loss: 0.78351 - Test loss: 0.53216
# Epoch 337 - lr: 0.01000 - Train loss: 0.78325 - Test loss: 0.53166
# Epoch 338 - lr: 0.01000 - Train loss: 0.78298 - Test loss: 0.53115
# Epoch 339 - lr: 0.01000 - Train loss: 0.78272 - Test loss: 0.53064
# Epoch 340 - lr: 0.01000 - Train loss: 0.78245 - Test loss: 0.53013
# Epoch 341 - lr: 0.01000 - Train loss: 0.78219 - Test loss: 0.52962
# Epoch 342 - lr: 0.01000 - Train loss: 0.78192 - Test loss: 0.52911
# Epoch 343 - lr: 0.01000 - Train loss: 0.78165 - Test loss: 0.52860
# Epoch 344 - lr: 0.01000 - Train loss: 0.78139 - Test loss: 0.52808
# Epoch 345 - lr: 0.01000 - Train loss: 0.78112 - Test loss: 0.52757
# Epoch 346 - lr: 0.01000 - Train loss: 0.78085 - Test loss: 0.52705
# Epoch 347 - lr: 0.01000 - Train loss: 0.78058 - Test loss: 0.52653
# Epoch 348 - lr: 0.01000 - Train loss: 0.78031 - Test loss: 0.52601
# Epoch 349 - lr: 0.01000 - Train loss: 0.78004 - Test loss: 0.52549
# Epoch 350 - lr: 0.01000 - Train loss: 0.77977 - Test loss: 0.52497
# Epoch 351 - lr: 0.01000 - Train loss: 0.77950 - Test loss: 0.52445
# Epoch 352 - lr: 0.01000 - Train loss: 0.77923 - Test loss: 0.52393
# Epoch 353 - lr: 0.01000 - Train loss: 0.77895 - Test loss: 0.52341
# Epoch 354 - lr: 0.01000 - Train loss: 0.77868 - Test loss: 0.52288
# Epoch 355 - lr: 0.01000 - Train loss: 0.77841 - Test loss: 0.52236
# Epoch 356 - lr: 0.01000 - Train loss: 0.77813 - Test loss: 0.52183
# Epoch 357 - lr: 0.01000 - Train loss: 0.77786 - Test loss: 0.52131
# Epoch 358 - lr: 0.01000 - Train loss: 0.77758 - Test loss: 0.52078
# Epoch 359 - lr: 0.01000 - Train loss: 0.77731 - Test loss: 0.52025
# Epoch 360 - lr: 0.01000 - Train loss: 0.77703 - Test loss: 0.51972
# Epoch 361 - lr: 0.01000 - Train loss: 0.77675 - Test loss: 0.51919
# Epoch 362 - lr: 0.01000 - Train loss: 0.77647 - Test loss: 0.51866
# Epoch 363 - lr: 0.01000 - Train loss: 0.77620 - Test loss: 0.51813
# Epoch 364 - lr: 0.01000 - Train loss: 0.77592 - Test loss: 0.51760
# Epoch 365 - lr: 0.01000 - Train loss: 0.77564 - Test loss: 0.51707
# Epoch 366 - lr: 0.01000 - Train loss: 0.77536 - Test loss: 0.51654
# Epoch 367 - lr: 0.01000 - Train loss: 0.77508 - Test loss: 0.51601
# Epoch 368 - lr: 0.01000 - Train loss: 0.77480 - Test loss: 0.51548
# Epoch 369 - lr: 0.01000 - Train loss: 0.77451 - Test loss: 0.51494
# Epoch 370 - lr: 0.01000 - Train loss: 0.77423 - Test loss: 0.51441
# Epoch 371 - lr: 0.01000 - Train loss: 0.77395 - Test loss: 0.51388
# Epoch 372 - lr: 0.01000 - Train loss: 0.77366 - Test loss: 0.51334
# Epoch 373 - lr: 0.01000 - Train loss: 0.77338 - Test loss: 0.51281
# Epoch 374 - lr: 0.01000 - Train loss: 0.77310 - Test loss: 0.51228
# Epoch 375 - lr: 0.01000 - Train loss: 0.77281 - Test loss: 0.51174
# Epoch 376 - lr: 0.01000 - Train loss: 0.77252 - Test loss: 0.51121
# Epoch 377 - lr: 0.01000 - Train loss: 0.77224 - Test loss: 0.51067
# Epoch 378 - lr: 0.01000 - Train loss: 0.77195 - Test loss: 0.51014
# Epoch 379 - lr: 0.01000 - Train loss: 0.77166 - Test loss: 0.50960
# Epoch 380 - lr: 0.01000 - Train loss: 0.77137 - Test loss: 0.50907
# Epoch 381 - lr: 0.01000 - Train loss: 0.77108 - Test loss: 0.50853
# Epoch 382 - lr: 0.01000 - Train loss: 0.77079 - Test loss: 0.50800
# Epoch 383 - lr: 0.01000 - Train loss: 0.77050 - Test loss: 0.50746
# Epoch 384 - lr: 0.01000 - Train loss: 0.77021 - Test loss: 0.50693
# Epoch 385 - lr: 0.01000 - Train loss: 0.76992 - Test loss: 0.50639
# Epoch 386 - lr: 0.01000 - Train loss: 0.76963 - Test loss: 0.50586
# Epoch 387 - lr: 0.01000 - Train loss: 0.76933 - Test loss: 0.50532
# Epoch 388 - lr: 0.01000 - Train loss: 0.76904 - Test loss: 0.50479
# Epoch 389 - lr: 0.01000 - Train loss: 0.76874 - Test loss: 0.50425
# Epoch 390 - lr: 0.01000 - Train loss: 0.76845 - Test loss: 0.50372
# Epoch 391 - lr: 0.01000 - Train loss: 0.76815 - Test loss: 0.50318
# Epoch 392 - lr: 0.01000 - Train loss: 0.76786 - Test loss: 0.50265
# Epoch 393 - lr: 0.01000 - Train loss: 0.76756 - Test loss: 0.50211
# Epoch 394 - lr: 0.01000 - Train loss: 0.76726 - Test loss: 0.50158
# Epoch 395 - lr: 0.01000 - Train loss: 0.76696 - Test loss: 0.50104
# Epoch 396 - lr: 0.01000 - Train loss: 0.76666 - Test loss: 0.50051
# Epoch 397 - lr: 0.01000 - Train loss: 0.76636 - Test loss: 0.49998
# Epoch 398 - lr: 0.01000 - Train loss: 0.76606 - Test loss: 0.49944
# Epoch 399 - lr: 0.01000 - Train loss: 0.76576 - Test loss: 0.49891
# Epoch 400 - lr: 0.01000 - Train loss: 0.76546 - Test loss: 0.49838
# Epoch 401 - lr: 0.01000 - Train loss: 0.76515 - Test loss: 0.49785
# Epoch 402 - lr: 0.01000 - Train loss: 0.76485 - Test loss: 0.49731
# Epoch 403 - lr: 0.01000 - Train loss: 0.76454 - Test loss: 0.49678
# Epoch 404 - lr: 0.01000 - Train loss: 0.76424 - Test loss: 0.49625
# Epoch 405 - lr: 0.01000 - Train loss: 0.76393 - Test loss: 0.49572
# Epoch 406 - lr: 0.01000 - Train loss: 0.76362 - Test loss: 0.49519
# Epoch 407 - lr: 0.01000 - Train loss: 0.76332 - Test loss: 0.49466
# Epoch 408 - lr: 0.01000 - Train loss: 0.76301 - Test loss: 0.49413
# Epoch 409 - lr: 0.01000 - Train loss: 0.76270 - Test loss: 0.49360
# Epoch 410 - lr: 0.01000 - Train loss: 0.76239 - Test loss: 0.49307
# Epoch 411 - lr: 0.01000 - Train loss: 0.76208 - Test loss: 0.49254
# Epoch 412 - lr: 0.01000 - Train loss: 0.76177 - Test loss: 0.49201
# Epoch 413 - lr: 0.01000 - Train loss: 0.76145 - Test loss: 0.49148
# Epoch 414 - lr: 0.01000 - Train loss: 0.76114 - Test loss: 0.49095
# Epoch 415 - lr: 0.01000 - Train loss: 0.76083 - Test loss: 0.49043
# Epoch 416 - lr: 0.01000 - Train loss: 0.76051 - Test loss: 0.48990
# Epoch 417 - lr: 0.01000 - Train loss: 0.76020 - Test loss: 0.48937
# Epoch 418 - lr: 0.01000 - Train loss: 0.75988 - Test loss: 0.48885
# Epoch 419 - lr: 0.01000 - Train loss: 0.75956 - Test loss: 0.48832
# Epoch 420 - lr: 0.01000 - Train loss: 0.75924 - Test loss: 0.48780
# Epoch 421 - lr: 0.01000 - Train loss: 0.75892 - Test loss: 0.48727
# Epoch 422 - lr: 0.01000 - Train loss: 0.75860 - Test loss: 0.48675
# Epoch 423 - lr: 0.01000 - Train loss: 0.75828 - Test loss: 0.48623
# Epoch 424 - lr: 0.01000 - Train loss: 0.75796 - Test loss: 0.48571
# Epoch 425 - lr: 0.01000 - Train loss: 0.75764 - Test loss: 0.48518
# Epoch 426 - lr: 0.01000 - Train loss: 0.75732 - Test loss: 0.48466
# Epoch 427 - lr: 0.01000 - Train loss: 0.75699 - Test loss: 0.48414
# Epoch 428 - lr: 0.01000 - Train loss: 0.75667 - Test loss: 0.48362
# Epoch 429 - lr: 0.01000 - Train loss: 0.75634 - Test loss: 0.48310
# Epoch 430 - lr: 0.01000 - Train loss: 0.75601 - Test loss: 0.48258
# Epoch 431 - lr: 0.01000 - Train loss: 0.75568 - Test loss: 0.48206
# Epoch 432 - lr: 0.01000 - Train loss: 0.75536 - Test loss: 0.48154
# Epoch 433 - lr: 0.01000 - Train loss: 0.75503 - Test loss: 0.48103
# Epoch 434 - lr: 0.01000 - Train loss: 0.75469 - Test loss: 0.48051
# Epoch 435 - lr: 0.01000 - Train loss: 0.75436 - Test loss: 0.47999
# Epoch 436 - lr: 0.01000 - Train loss: 0.75403 - Test loss: 0.47948
# Epoch 437 - lr: 0.01000 - Train loss: 0.75370 - Test loss: 0.47896
# Epoch 438 - lr: 0.01000 - Train loss: 0.75336 - Test loss: 0.47845
# Epoch 439 - lr: 0.01000 - Train loss: 0.75303 - Test loss: 0.47793
# Epoch 440 - lr: 0.01000 - Train loss: 0.75269 - Test loss: 0.47742
# Epoch 441 - lr: 0.01000 - Train loss: 0.75235 - Test loss: 0.47690
# Epoch 442 - lr: 0.01000 - Train loss: 0.75201 - Test loss: 0.47639
# Epoch 443 - lr: 0.01000 - Train loss: 0.75167 - Test loss: 0.47588
# Epoch 444 - lr: 0.01000 - Train loss: 0.75133 - Test loss: 0.47537
# Epoch 445 - lr: 0.01000 - Train loss: 0.75099 - Test loss: 0.47486
# Epoch 446 - lr: 0.01000 - Train loss: 0.75065 - Test loss: 0.47435
# Epoch 447 - lr: 0.01000 - Train loss: 0.75030 - Test loss: 0.47384
# Epoch 448 - lr: 0.01000 - Train loss: 0.74996 - Test loss: 0.47333
# Epoch 449 - lr: 0.01000 - Train loss: 0.74961 - Test loss: 0.47282
# Epoch 450 - lr: 0.01000 - Train loss: 0.74927 - Test loss: 0.47231
# Epoch 451 - lr: 0.01000 - Train loss: 0.74892 - Test loss: 0.47181
# Epoch 452 - lr: 0.01000 - Train loss: 0.74857 - Test loss: 0.47130
# Epoch 453 - lr: 0.01000 - Train loss: 0.74822 - Test loss: 0.47080
# Epoch 454 - lr: 0.01000 - Train loss: 0.74787 - Test loss: 0.47029
# Epoch 455 - lr: 0.01000 - Train loss: 0.74751 - Test loss: 0.46979
# Epoch 456 - lr: 0.01000 - Train loss: 0.74716 - Test loss: 0.46928
# Epoch 457 - lr: 0.01000 - Train loss: 0.74681 - Test loss: 0.46878
# Epoch 458 - lr: 0.01000 - Train loss: 0.74645 - Test loss: 0.46828
# Epoch 459 - lr: 0.01000 - Train loss: 0.74609 - Test loss: 0.46777
# Epoch 460 - lr: 0.01000 - Train loss: 0.74573 - Test loss: 0.46727
# Epoch 461 - lr: 0.01000 - Train loss: 0.74537 - Test loss: 0.46677
# Epoch 462 - lr: 0.01000 - Train loss: 0.74501 - Test loss: 0.46627
# Epoch 463 - lr: 0.01000 - Train loss: 0.74465 - Test loss: 0.46577
# Epoch 464 - lr: 0.01000 - Train loss: 0.74429 - Test loss: 0.46527
# Epoch 465 - lr: 0.01000 - Train loss: 0.74392 - Test loss: 0.46477
# Epoch 466 - lr: 0.01000 - Train loss: 0.74356 - Test loss: 0.46427
# Epoch 467 - lr: 0.01000 - Train loss: 0.74319 - Test loss: 0.46378
# Epoch 468 - lr: 0.01000 - Train loss: 0.74282 - Test loss: 0.46328
# Epoch 469 - lr: 0.01000 - Train loss: 0.74245 - Test loss: 0.46278
# Epoch 470 - lr: 0.01000 - Train loss: 0.74208 - Test loss: 0.46229
# Epoch 471 - lr: 0.01000 - Train loss: 0.74171 - Test loss: 0.46179
# Epoch 472 - lr: 0.01000 - Train loss: 0.74134 - Test loss: 0.46129
# Epoch 473 - lr: 0.01000 - Train loss: 0.74096 - Test loss: 0.46080
# Epoch 474 - lr: 0.01000 - Train loss: 0.74059 - Test loss: 0.46031
# Epoch 475 - lr: 0.01000 - Train loss: 0.74021 - Test loss: 0.45981
# Epoch 476 - lr: 0.01000 - Train loss: 0.73983 - Test loss: 0.45932
# Epoch 477 - lr: 0.01000 - Train loss: 0.73945 - Test loss: 0.45883
# Epoch 478 - lr: 0.01000 - Train loss: 0.73907 - Test loss: 0.45834
# Epoch 479 - lr: 0.01000 - Train loss: 0.73869 - Test loss: 0.45784
# Epoch 480 - lr: 0.01000 - Train loss: 0.73830 - Test loss: 0.45735
# Epoch 481 - lr: 0.01000 - Train loss: 0.73792 - Test loss: 0.45686
# Epoch 482 - lr: 0.01000 - Train loss: 0.73753 - Test loss: 0.45637
# Epoch 483 - lr: 0.01000 - Train loss: 0.73714 - Test loss: 0.45588
# Epoch 484 - lr: 0.01000 - Train loss: 0.73675 - Test loss: 0.45539
# Epoch 485 - lr: 0.01000 - Train loss: 0.73636 - Test loss: 0.45490
# Epoch 486 - lr: 0.01000 - Train loss: 0.73597 - Test loss: 0.45442
# Epoch 487 - lr: 0.01000 - Train loss: 0.73557 - Test loss: 0.45393
# Epoch 488 - lr: 0.01000 - Train loss: 0.73518 - Test loss: 0.45344
# Epoch 489 - lr: 0.01000 - Train loss: 0.73478 - Test loss: 0.45295
# Epoch 490 - lr: 0.01000 - Train loss: 0.73438 - Test loss: 0.45247
# Epoch 491 - lr: 0.01000 - Train loss: 0.73398 - Test loss: 0.45198
# Epoch 492 - lr: 0.01000 - Train loss: 0.73358 - Test loss: 0.45150
# Epoch 493 - lr: 0.01000 - Train loss: 0.73317 - Test loss: 0.45101
# Epoch 494 - lr: 0.01000 - Train loss: 0.73277 - Test loss: 0.45053
# Epoch 495 - lr: 0.01000 - Train loss: 0.73236 - Test loss: 0.45004
# Epoch 496 - lr: 0.01000 - Train loss: 0.73195 - Test loss: 0.44956
# Epoch 497 - lr: 0.01000 - Train loss: 0.73154 - Test loss: 0.44907
# Epoch 498 - lr: 0.01000 - Train loss: 0.73113 - Test loss: 0.44859
# Epoch 499 - lr: 0.01000 - Train loss: 0.73071 - Test loss: 0.44810
# Epoch 500 - lr: 0.01000 - Train loss: 0.73030 - Test loss: 0.44762
# Epoch 501 - lr: 0.01000 - Train loss: 0.72988 - Test loss: 0.44714
# Epoch 502 - lr: 0.01000 - Train loss: 0.72946 - Test loss: 0.44666
# Epoch 503 - lr: 0.01000 - Train loss: 0.72904 - Test loss: 0.44617
# Epoch 504 - lr: 0.01000 - Train loss: 0.72862 - Test loss: 0.44569
# Epoch 505 - lr: 0.01000 - Train loss: 0.72819 - Test loss: 0.44521
# Epoch 506 - lr: 0.01000 - Train loss: 0.72777 - Test loss: 0.44473
# Epoch 507 - lr: 0.01000 - Train loss: 0.72734 - Test loss: 0.44425
# Epoch 508 - lr: 0.01000 - Train loss: 0.72691 - Test loss: 0.44376
# Epoch 509 - lr: 0.01000 - Train loss: 0.72648 - Test loss: 0.44328
# Epoch 510 - lr: 0.01000 - Train loss: 0.72604 - Test loss: 0.44280
# Epoch 511 - lr: 0.01000 - Train loss: 0.72561 - Test loss: 0.44232
# Epoch 512 - lr: 0.01000 - Train loss: 0.72517 - Test loss: 0.44184
# Epoch 513 - lr: 0.01000 - Train loss: 0.72473 - Test loss: 0.44136
# Epoch 514 - lr: 0.01000 - Train loss: 0.72429 - Test loss: 0.44088
# Epoch 515 - lr: 0.01000 - Train loss: 0.72385 - Test loss: 0.44040
# Epoch 516 - lr: 0.01000 - Train loss: 0.72340 - Test loss: 0.43992
# Epoch 517 - lr: 0.01000 - Train loss: 0.72295 - Test loss: 0.43944
# Epoch 518 - lr: 0.01000 - Train loss: 0.72250 - Test loss: 0.43896
# Epoch 519 - lr: 0.01000 - Train loss: 0.72205 - Test loss: 0.43848
# Epoch 520 - lr: 0.01000 - Train loss: 0.72160 - Test loss: 0.43800
# Epoch 521 - lr: 0.01000 - Train loss: 0.72114 - Test loss: 0.43752
# Epoch 522 - lr: 0.01000 - Train loss: 0.72069 - Test loss: 0.43704
# Epoch 523 - lr: 0.01000 - Train loss: 0.72022 - Test loss: 0.43656
# Epoch 524 - lr: 0.01000 - Train loss: 0.71976 - Test loss: 0.43608
# Epoch 525 - lr: 0.01000 - Train loss: 0.71930 - Test loss: 0.43560
# Epoch 526 - lr: 0.01000 - Train loss: 0.71883 - Test loss: 0.43512
# Epoch 527 - lr: 0.01000 - Train loss: 0.71836 - Test loss: 0.43464
# Epoch 528 - lr: 0.01000 - Train loss: 0.71789 - Test loss: 0.43416
# Epoch 529 - lr: 0.01000 - Train loss: 0.71742 - Test loss: 0.43368
# Epoch 530 - lr: 0.01000 - Train loss: 0.71694 - Test loss: 0.43320
# Epoch 531 - lr: 0.01000 - Train loss: 0.71646 - Test loss: 0.43272
# Epoch 532 - lr: 0.01000 - Train loss: 0.71598 - Test loss: 0.43224
# Epoch 533 - lr: 0.01000 - Train loss: 0.71550 - Test loss: 0.43176
# Epoch 534 - lr: 0.01000 - Train loss: 0.71501 - Test loss: 0.43128
# Epoch 535 - lr: 0.01000 - Train loss: 0.71452 - Test loss: 0.43079
# Epoch 536 - lr: 0.01000 - Train loss: 0.71403 - Test loss: 0.43031
# Epoch 537 - lr: 0.01000 - Train loss: 0.71354 - Test loss: 0.42983
# Epoch 538 - lr: 0.01000 - Train loss: 0.71305 - Test loss: 0.42935
# Epoch 539 - lr: 0.01000 - Train loss: 0.71255 - Test loss: 0.42887
# Epoch 540 - lr: 0.01000 - Train loss: 0.71205 - Test loss: 0.42838
# Epoch 541 - lr: 0.01000 - Train loss: 0.71154 - Test loss: 0.42790
# Epoch 542 - lr: 0.01000 - Train loss: 0.71104 - Test loss: 0.42742
# Epoch 543 - lr: 0.01000 - Train loss: 0.71053 - Test loss: 0.42693
# Epoch 544 - lr: 0.01000 - Train loss: 0.71002 - Test loss: 0.42645
# Epoch 545 - lr: 0.01000 - Train loss: 0.70950 - Test loss: 0.42597
# Epoch 546 - lr: 0.01000 - Train loss: 0.70899 - Test loss: 0.42548
# Epoch 547 - lr: 0.01000 - Train loss: 0.70847 - Test loss: 0.42499
# Epoch 548 - lr: 0.01000 - Train loss: 0.70794 - Test loss: 0.42451
# Epoch 549 - lr: 0.01000 - Train loss: 0.70742 - Test loss: 0.42402
# Epoch 550 - lr: 0.01000 - Train loss: 0.70689 - Test loss: 0.42354
# Epoch 551 - lr: 0.01000 - Train loss: 0.70636 - Test loss: 0.42305
# Epoch 552 - lr: 0.01000 - Train loss: 0.70582 - Test loss: 0.42256
# Epoch 553 - lr: 0.01000 - Train loss: 0.70529 - Test loss: 0.42207
# Epoch 554 - lr: 0.01000 - Train loss: 0.70475 - Test loss: 0.42158
# Epoch 555 - lr: 0.01000 - Train loss: 0.70420 - Test loss: 0.42109
# Epoch 556 - lr: 0.01000 - Train loss: 0.70366 - Test loss: 0.42060
# Epoch 557 - lr: 0.01000 - Train loss: 0.70311 - Test loss: 0.42011
# Epoch 558 - lr: 0.01000 - Train loss: 0.70256 - Test loss: 0.41962
# Epoch 559 - lr: 0.01000 - Train loss: 0.70200 - Test loss: 0.41913
# Epoch 560 - lr: 0.01000 - Train loss: 0.70144 - Test loss: 0.41863
# Epoch 561 - lr: 0.01000 - Train loss: 0.70088 - Test loss: 0.41814
# Epoch 562 - lr: 0.01000 - Train loss: 0.70031 - Test loss: 0.41764
# Epoch 563 - lr: 0.01000 - Train loss: 0.69974 - Test loss: 0.41715
# Epoch 564 - lr: 0.01000 - Train loss: 0.69917 - Test loss: 0.41665
# Epoch 565 - lr: 0.01000 - Train loss: 0.69860 - Test loss: 0.41615
# Epoch 566 - lr: 0.01000 - Train loss: 0.69802 - Test loss: 0.41565
# Epoch 567 - lr: 0.01000 - Train loss: 0.69743 - Test loss: 0.41516
# Epoch 568 - lr: 0.01000 - Train loss: 0.69685 - Test loss: 0.41466
# Epoch 569 - lr: 0.01000 - Train loss: 0.69626 - Test loss: 0.41415
# Epoch 570 - lr: 0.01000 - Train loss: 0.69567 - Test loss: 0.41365
# Epoch 571 - lr: 0.01000 - Train loss: 0.69507 - Test loss: 0.41315
# Epoch 572 - lr: 0.01000 - Train loss: 0.69447 - Test loss: 0.41264
# Epoch 573 - lr: 0.01000 - Train loss: 0.69386 - Test loss: 0.41214
# Epoch 574 - lr: 0.01000 - Train loss: 0.69326 - Test loss: 0.41163
# Epoch 575 - lr: 0.01000 - Train loss: 0.69264 - Test loss: 0.41112
# Epoch 576 - lr: 0.01000 - Train loss: 0.69203 - Test loss: 0.41062
# Epoch 577 - lr: 0.01000 - Train loss: 0.69141 - Test loss: 0.41011
# Epoch 578 - lr: 0.01000 - Train loss: 0.69078 - Test loss: 0.40959
# Epoch 579 - lr: 0.01000 - Train loss: 0.69016 - Test loss: 0.40908
# Epoch 580 - lr: 0.01000 - Train loss: 0.68953 - Test loss: 0.40857
# Epoch 581 - lr: 0.01000 - Train loss: 0.68889 - Test loss: 0.40805
# Epoch 582 - lr: 0.01000 - Train loss: 0.68825 - Test loss: 0.40754
# Epoch 583 - lr: 0.01000 - Train loss: 0.68761 - Test loss: 0.40702
# Epoch 584 - lr: 0.01000 - Train loss: 0.68696 - Test loss: 0.40650
# Epoch 585 - lr: 0.01000 - Train loss: 0.68631 - Test loss: 0.40598
# Epoch 586 - lr: 0.01000 - Train loss: 0.68565 - Test loss: 0.40546
# Epoch 587 - lr: 0.01000 - Train loss: 0.68499 - Test loss: 0.40493
# Epoch 588 - lr: 0.01000 - Train loss: 0.68432 - Test loss: 0.40441
# Epoch 589 - lr: 0.01000 - Train loss: 0.68365 - Test loss: 0.40388
# Epoch 590 - lr: 0.01000 - Train loss: 0.68298 - Test loss: 0.40335
# Epoch 591 - lr: 0.01000 - Train loss: 0.68230 - Test loss: 0.40282
# Epoch 592 - lr: 0.01000 - Train loss: 0.68161 - Test loss: 0.40229
# Epoch 593 - lr: 0.01000 - Train loss: 0.68093 - Test loss: 0.40176
# Epoch 594 - lr: 0.01000 - Train loss: 0.68023 - Test loss: 0.40122
# Epoch 595 - lr: 0.01000 - Train loss: 0.67953 - Test loss: 0.40068
# Epoch 596 - lr: 0.01000 - Train loss: 0.67883 - Test loss: 0.40015
# Epoch 597 - lr: 0.01000 - Train loss: 0.67812 - Test loss: 0.39960
# Epoch 598 - lr: 0.01000 - Train loss: 0.67741 - Test loss: 0.39906
# Epoch 599 - lr: 0.01000 - Train loss: 0.67669 - Test loss: 0.39852
# Epoch 600 - lr: 0.01000 - Train loss: 0.67597 - Test loss: 0.39797
# Epoch 601 - lr: 0.01000 - Train loss: 0.67524 - Test loss: 0.39742
# Epoch 602 - lr: 0.01000 - Train loss: 0.67451 - Test loss: 0.39687
# Epoch 603 - lr: 0.01000 - Train loss: 0.67377 - Test loss: 0.39632
# Epoch 604 - lr: 0.01000 - Train loss: 0.67303 - Test loss: 0.39577
# Epoch 605 - lr: 0.01000 - Train loss: 0.67228 - Test loss: 0.39521
# Epoch 606 - lr: 0.01000 - Train loss: 0.67152 - Test loss: 0.39465
# Epoch 607 - lr: 0.01000 - Train loss: 0.67076 - Test loss: 0.39409
# Epoch 608 - lr: 0.01000 - Train loss: 0.67000 - Test loss: 0.39352
# Epoch 609 - lr: 0.01000 - Train loss: 0.66923 - Test loss: 0.39296
# Epoch 610 - lr: 0.01000 - Train loss: 0.66845 - Test loss: 0.39239
# Epoch 611 - lr: 0.01000 - Train loss: 0.66767 - Test loss: 0.39182
# Epoch 612 - lr: 0.01000 - Train loss: 0.66688 - Test loss: 0.39125
# Epoch 613 - lr: 0.01000 - Train loss: 0.66608 - Test loss: 0.39067
# Epoch 614 - lr: 0.01000 - Train loss: 0.66528 - Test loss: 0.39009
# Epoch 615 - lr: 0.01000 - Train loss: 0.66448 - Test loss: 0.38951
# Epoch 616 - lr: 0.01000 - Train loss: 0.66366 - Test loss: 0.38893
# Epoch 617 - lr: 0.01000 - Train loss: 0.66285 - Test loss: 0.38834
# Epoch 618 - lr: 0.01000 - Train loss: 0.66202 - Test loss: 0.38775
# Epoch 619 - lr: 0.01000 - Train loss: 0.66119 - Test loss: 0.38716
# Epoch 620 - lr: 0.01000 - Train loss: 0.66035 - Test loss: 0.38657
# Epoch 621 - lr: 0.01000 - Train loss: 0.65951 - Test loss: 0.38597
# Epoch 622 - lr: 0.01000 - Train loss: 0.65866 - Test loss: 0.38537
# Epoch 623 - lr: 0.01000 - Train loss: 0.65780 - Test loss: 0.38477
# Epoch 624 - lr: 0.01000 - Train loss: 0.65693 - Test loss: 0.38416
# Epoch 625 - lr: 0.01000 - Train loss: 0.65606 - Test loss: 0.38355
# Epoch 626 - lr: 0.01000 - Train loss: 0.65518 - Test loss: 0.38294
# Epoch 627 - lr: 0.01000 - Train loss: 0.65430 - Test loss: 0.38233
# Epoch 628 - lr: 0.01000 - Train loss: 0.65341 - Test loss: 0.38171
# Epoch 629 - lr: 0.01000 - Train loss: 0.65251 - Test loss: 0.38109
# Epoch 630 - lr: 0.01000 - Train loss: 0.65160 - Test loss: 0.38046
# Epoch 631 - lr: 0.01000 - Train loss: 0.65069 - Test loss: 0.37983
# Epoch 632 - lr: 0.01000 - Train loss: 0.64977 - Test loss: 0.37920
# Epoch 633 - lr: 0.01000 - Train loss: 0.64884 - Test loss: 0.37857
# Epoch 634 - lr: 0.01000 - Train loss: 0.64790 - Test loss: 0.37793
# Epoch 635 - lr: 0.01000 - Train loss: 0.64696 - Test loss: 0.37729
# Epoch 636 - lr: 0.01000 - Train loss: 0.64601 - Test loss: 0.37664
# Epoch 637 - lr: 0.01000 - Train loss: 0.64505 - Test loss: 0.37599
# Epoch 638 - lr: 0.01000 - Train loss: 0.64408 - Test loss: 0.37534
# Epoch 639 - lr: 0.01000 - Train loss: 0.64311 - Test loss: 0.37468
# Epoch 640 - lr: 0.01000 - Train loss: 0.64212 - Test loss: 0.37402
# Epoch 641 - lr: 0.01000 - Train loss: 0.64113 - Test loss: 0.37335
# Epoch 642 - lr: 0.01000 - Train loss: 0.64013 - Test loss: 0.37269
# Epoch 643 - lr: 0.01000 - Train loss: 0.63912 - Test loss: 0.37201
# Epoch 644 - lr: 0.01000 - Train loss: 0.63811 - Test loss: 0.37134
# Epoch 645 - lr: 0.01000 - Train loss: 0.63708 - Test loss: 0.37066
# Epoch 646 - lr: 0.01000 - Train loss: 0.63605 - Test loss: 0.36997
# Epoch 647 - lr: 0.01000 - Train loss: 0.63501 - Test loss: 0.36928
# Epoch 648 - lr: 0.01000 - Train loss: 0.63395 - Test loss: 0.36859
# Epoch 649 - lr: 0.01000 - Train loss: 0.63289 - Test loss: 0.36789
# Epoch 650 - lr: 0.01000 - Train loss: 0.63182 - Test loss: 0.36719
# Epoch 651 - lr: 0.01000 - Train loss: 0.63074 - Test loss: 0.36648
# Epoch 652 - lr: 0.01000 - Train loss: 0.62965 - Test loss: 0.36577
# Epoch 653 - lr: 0.01000 - Train loss: 0.62856 - Test loss: 0.36505
# Epoch 654 - lr: 0.01000 - Train loss: 0.62745 - Test loss: 0.36433
# Epoch 655 - lr: 0.01000 - Train loss: 0.62633 - Test loss: 0.36360
# Epoch 656 - lr: 0.01000 - Train loss: 0.62520 - Test loss: 0.36287
# Epoch 657 - lr: 0.01000 - Train loss: 0.62407 - Test loss: 0.36214
# Epoch 658 - lr: 0.01000 - Train loss: 0.62292 - Test loss: 0.36139
# Epoch 659 - lr: 0.01000 - Train loss: 0.62176 - Test loss: 0.36065
# Epoch 660 - lr: 0.01000 - Train loss: 0.62060 - Test loss: 0.35990
# Epoch 661 - lr: 0.01000 - Train loss: 0.61942 - Test loss: 0.35914
# Epoch 662 - lr: 0.01000 - Train loss: 0.61823 - Test loss: 0.35838
# Epoch 663 - lr: 0.01000 - Train loss: 0.61703 - Test loss: 0.35761
# Epoch 664 - lr: 0.01000 - Train loss: 0.61582 - Test loss: 0.35684
# Epoch 665 - lr: 0.01000 - Train loss: 0.61460 - Test loss: 0.35606
# Epoch 666 - lr: 0.01000 - Train loss: 0.61337 - Test loss: 0.35528
# Epoch 667 - lr: 0.01000 - Train loss: 0.61212 - Test loss: 0.35449
# Epoch 668 - lr: 0.01000 - Train loss: 0.61087 - Test loss: 0.35369
# Epoch 669 - lr: 0.01000 - Train loss: 0.60960 - Test loss: 0.35289
# Epoch 670 - lr: 0.01000 - Train loss: 0.60833 - Test loss: 0.35209
# Epoch 671 - lr: 0.01000 - Train loss: 0.60704 - Test loss: 0.35127
# Epoch 672 - lr: 0.01000 - Train loss: 0.60574 - Test loss: 0.35045
# Epoch 673 - lr: 0.01000 - Train loss: 0.60442 - Test loss: 0.34963
# Epoch 674 - lr: 0.01000 - Train loss: 0.60310 - Test loss: 0.34880
# Epoch 675 - lr: 0.01000 - Train loss: 0.60176 - Test loss: 0.34796
# Epoch 676 - lr: 0.01000 - Train loss: 0.60041 - Test loss: 0.34712
# Epoch 677 - lr: 0.01000 - Train loss: 0.59905 - Test loss: 0.34627
# Epoch 678 - lr: 0.01000 - Train loss: 0.59768 - Test loss: 0.34541
# Epoch 679 - lr: 0.01000 - Train loss: 0.59629 - Test loss: 0.34455
# Epoch 680 - lr: 0.01000 - Train loss: 0.59489 - Test loss: 0.34368
# Epoch 681 - lr: 0.01000 - Train loss: 0.59348 - Test loss: 0.34280
# Epoch 682 - lr: 0.01000 - Train loss: 0.59205 - Test loss: 0.34191
# Epoch 683 - lr: 0.01000 - Train loss: 0.59061 - Test loss: 0.34102
# Epoch 684 - lr: 0.01000 - Train loss: 0.58916 - Test loss: 0.34012
# Epoch 685 - lr: 0.01000 - Train loss: 0.58769 - Test loss: 0.33922
# Epoch 686 - lr: 0.01000 - Train loss: 0.58621 - Test loss: 0.33831
# Epoch 687 - lr: 0.01000 - Train loss: 0.58471 - Test loss: 0.33739
# Epoch 688 - lr: 0.01000 - Train loss: 0.58320 - Test loss: 0.33646
# Epoch 689 - lr: 0.01000 - Train loss: 0.58168 - Test loss: 0.33552
# Epoch 690 - lr: 0.01000 - Train loss: 0.58014 - Test loss: 0.33458
# Epoch 691 - lr: 0.01000 - Train loss: 0.57859 - Test loss: 0.33363
# Epoch 692 - lr: 0.01000 - Train loss: 0.57702 - Test loss: 0.33267
# Epoch 693 - lr: 0.01000 - Train loss: 0.57544 - Test loss: 0.33171
# Epoch 694 - lr: 0.01000 - Train loss: 0.57384 - Test loss: 0.33073
# Epoch 695 - lr: 0.01000 - Train loss: 0.57223 - Test loss: 0.32975
# Epoch 696 - lr: 0.01000 - Train loss: 0.57060 - Test loss: 0.32876
# Epoch 697 - lr: 0.01000 - Train loss: 0.56896 - Test loss: 0.32776
# Epoch 698 - lr: 0.01000 - Train loss: 0.56730 - Test loss: 0.32675
# Epoch 699 - lr: 0.01000 - Train loss: 0.56563 - Test loss: 0.32574
# Epoch 700 - lr: 0.01000 - Train loss: 0.56393 - Test loss: 0.32471
# Epoch 701 - lr: 0.01000 - Train loss: 0.56223 - Test loss: 0.32368
# Epoch 702 - lr: 0.01000 - Train loss: 0.56050 - Test loss: 0.32264
# Epoch 703 - lr: 0.01000 - Train loss: 0.55876 - Test loss: 0.32159
# Epoch 704 - lr: 0.01000 - Train loss: 0.55701 - Test loss: 0.32053
# Epoch 705 - lr: 0.01000 - Train loss: 0.55523 - Test loss: 0.31946
# Epoch 706 - lr: 0.01000 - Train loss: 0.55344 - Test loss: 0.31838
# Epoch 707 - lr: 0.01000 - Train loss: 0.55164 - Test loss: 0.31730
# Epoch 708 - lr: 0.01000 - Train loss: 0.54981 - Test loss: 0.31620
# Epoch 709 - lr: 0.01000 - Train loss: 0.54797 - Test loss: 0.31509
# Epoch 710 - lr: 0.01000 - Train loss: 0.54611 - Test loss: 0.31398
# Epoch 711 - lr: 0.01000 - Train loss: 0.54423 - Test loss: 0.31285
# Epoch 712 - lr: 0.01000 - Train loss: 0.54233 - Test loss: 0.31172
# Epoch 713 - lr: 0.01000 - Train loss: 0.54042 - Test loss: 0.31057
# Epoch 714 - lr: 0.01000 - Train loss: 0.53849 - Test loss: 0.30942
# Epoch 715 - lr: 0.01000 - Train loss: 0.53653 - Test loss: 0.30826
# Epoch 716 - lr: 0.01000 - Train loss: 0.53456 - Test loss: 0.30708
# Epoch 717 - lr: 0.01000 - Train loss: 0.53258 - Test loss: 0.30590
# Epoch 718 - lr: 0.01000 - Train loss: 0.53057 - Test loss: 0.30470
# ...
# Epoch 4766 - lr: 0.01000 - Train loss: 0.04057 - Test loss: 0.05062
# Epoch 4767 - lr: 0.01000 - Train loss: 0.04057 - Test loss: 0.05062
# Epoch 4768 - lr: 0.01000 - Train loss: 0.04056 - Test loss: 0.05062
# Epoch 4769 - lr: 0.01000 - Train loss: 0.04056 - Test loss: 0.05062
# Epoch 4770 - lr: 0.01000 - Train loss: 0.04055 - Test loss: 0.05062
# Epoch 4771 - lr: 0.01000 - Train loss: 0.04055 - Test loss: 0.05062
# Epoch 4772 - lr: 0.01000 - Train loss: 0.04055 - Test loss: 0.05062
# Epoch 4773 - lr: 0.01000 - Train loss: 0.04054 - Test loss: 0.05062
# Epoch 4774 - lr: 0.01000 - Train loss: 0.04054 - Test loss: 0.05062
# Epoch 4775 - lr: 0.01000 - Train loss: 0.04053 - Test loss: 0.05062
# Epoch 4776 - lr: 0.01000 - Train loss: 0.04053 - Test loss: 0.05062
# Epoch 4777 - lr: 0.01000 - Train loss: 0.04053 - Test loss: 0.05062
# Epoch 4778 - lr: 0.01000 - Train loss: 0.04052 - Test loss: 0.05062
# Epoch 4779 - lr: 0.01000 - Train loss: 0.04052 - Test loss: 0.05062
# Epoch 4780 - lr: 0.01000 - Train loss: 0.04052 - Test loss: 0.05062
# Epoch 4781 - lr: 0.01000 - Train loss: 0.04051 - Test loss: 0.05062
# Epoch 4782 - lr: 0.01000 - Train loss: 0.04051 - Test loss: 0.05062
# Epoch 4783 - lr: 0.01000 - Train loss: 0.04050 - Test loss: 0.05062
# Epoch 4784 - lr: 0.01000 - Train loss: 0.04050 - Test loss: 0.05062
# Epoch 4785 - lr: 0.01000 - Train loss: 0.04050 - Test loss: 0.05062
# Epoch 4786 - lr: 0.01000 - Train loss: 0.04049 - Test loss: 0.05062
# Epoch 4787 - lr: 0.01000 - Train loss: 0.04049 - Test loss: 0.05062
# Epoch 4788 - lr: 0.01000 - Train loss: 0.04048 - Test loss: 0.05062
# Epoch 4789 - lr: 0.01000 - Train loss: 0.04048 - Test loss: 0.05062
# Epoch 4790 - lr: 0.01000 - Train loss: 0.04048 - Test loss: 0.05062
# Epoch 4791 - lr: 0.01000 - Train loss: 0.04047 - Test loss: 0.05062
# Epoch 4792 - lr: 0.01000 - Train loss: 0.04047 - Test loss: 0.05062
# Epoch 4793 - lr: 0.01000 - Train loss: 0.04046 - Test loss: 0.05062
# Epoch 4794 - lr: 0.01000 - Train loss: 0.04046 - Test loss: 0.05062
# Epoch 4795 - lr: 0.01000 - Train loss: 0.04046 - Test loss: 0.05062
# Epoch 4796 - lr: 0.01000 - Train loss: 0.04045 - Test loss: 0.05061
# Epoch 4797 - lr: 0.01000 - Train loss: 0.04045 - Test loss: 0.05061
# Epoch 4798 - lr: 0.01000 - Train loss: 0.04045 - Test loss: 0.05061
# Epoch 4799 - lr: 0.01000 - Train loss: 0.04044 - Test loss: 0.05061
# Epoch 4800 - lr: 0.01000 - Train loss: 0.04044 - Test loss: 0.05061
# Epoch 4801 - lr: 0.01000 - Train loss: 0.04043 - Test loss: 0.05061
# Epoch 4802 - lr: 0.01000 - Train loss: 0.04043 - Test loss: 0.05061
# Epoch 4803 - lr: 0.01000 - Train loss: 0.04043 - Test loss: 0.05061
# Epoch 4804 - lr: 0.01000 - Train loss: 0.04042 - Test loss: 0.05061
# Epoch 4805 - lr: 0.01000 - Train loss: 0.04042 - Test loss: 0.05061
# Epoch 4806 - lr: 0.01000 - Train loss: 0.04041 - Test loss: 0.05061
# Epoch 4807 - lr: 0.01000 - Train loss: 0.04041 - Test loss: 0.05061
# Epoch 4808 - lr: 0.01000 - Train loss: 0.04041 - Test loss: 0.05061
# Epoch 4809 - lr: 0.01000 - Train loss: 0.04040 - Test loss: 0.05061
# Epoch 4810 - lr: 0.01000 - Train loss: 0.04040 - Test loss: 0.05061
# Epoch 4811 - lr: 0.01000 - Train loss: 0.04039 - Test loss: 0.05061
# Epoch 4812 - lr: 0.01000 - Train loss: 0.04039 - Test loss: 0.05061
# Epoch 4813 - lr: 0.01000 - Train loss: 0.04039 - Test loss: 0.05061
# Epoch 4814 - lr: 0.01000 - Train loss: 0.04038 - Test loss: 0.05061
# Epoch 4815 - lr: 0.01000 - Train loss: 0.04038 - Test loss: 0.05061
# Epoch 4816 - lr: 0.01000 - Train loss: 0.04038 - Test loss: 0.05061
# Epoch 4817 - lr: 0.01000 - Train loss: 0.04037 - Test loss: 0.05061
# Epoch 4818 - lr: 0.01000 - Train loss: 0.04037 - Test loss: 0.05061
# Epoch 4819 - lr: 0.01000 - Train loss: 0.04036 - Test loss: 0.05061
# Epoch 4820 - lr: 0.01000 - Train loss: 0.04036 - Test loss: 0.05061
# Epoch 4821 - lr: 0.01000 - Train loss: 0.04036 - Test loss: 0.05061
# Epoch 4822 - lr: 0.01000 - Train loss: 0.04035 - Test loss: 0.05061
# Epoch 4823 - lr: 0.01000 - Train loss: 0.04035 - Test loss: 0.05061
# Epoch 4824 - lr: 0.01000 - Train loss: 0.04034 - Test loss: 0.05061
# Epoch 4825 - lr: 0.01000 - Train loss: 0.04034 - Test loss: 0.05061
# Epoch 4826 - lr: 0.01000 - Train loss: 0.04034 - Test loss: 0.05061
# Epoch 4827 - lr: 0.01000 - Train loss: 0.04033 - Test loss: 0.05061
# Epoch 4828 - lr: 0.01000 - Train loss: 0.04033 - Test loss: 0.05061
# Epoch 4829 - lr: 0.01000 - Train loss: 0.04032 - Test loss: 0.05061
# Epoch 4830 - lr: 0.01000 - Train loss: 0.04032 - Test loss: 0.05061
# Epoch 4831 - lr: 0.01000 - Train loss: 0.04032 - Test loss: 0.05061
# Epoch 4832 - lr: 0.01000 - Train loss: 0.04031 - Test loss: 0.05061
# Epoch 4833 - lr: 0.01000 - Train loss: 0.04031 - Test loss: 0.05061
# Epoch 4834 - lr: 0.01000 - Train loss: 0.04030 - Test loss: 0.05060
# Epoch 4835 - lr: 0.01000 - Train loss: 0.04030 - Test loss: 0.05060
# Epoch 4836 - lr: 0.01000 - Train loss: 0.04030 - Test loss: 0.05060
# Epoch 4837 - lr: 0.01000 - Train loss: 0.04029 - Test loss: 0.05060
# Epoch 4838 - lr: 0.01000 - Train loss: 0.04029 - Test loss: 0.05060
# Epoch 4839 - lr: 0.01000 - Train loss: 0.04029 - Test loss: 0.05060
# Epoch 4840 - lr: 0.01000 - Train loss: 0.04028 - Test loss: 0.05060
# Epoch 4841 - lr: 0.01000 - Train loss: 0.04028 - Test loss: 0.05060
# Epoch 4842 - lr: 0.01000 - Train loss: 0.04027 - Test loss: 0.05060
# Epoch 4843 - lr: 0.01000 - Train loss: 0.04027 - Test loss: 0.05060
# Epoch 4844 - lr: 0.01000 - Train loss: 0.04027 - Test loss: 0.05060
# Epoch 4845 - lr: 0.01000 - Train loss: 0.04026 - Test loss: 0.05060
# Epoch 4846 - lr: 0.01000 - Train loss: 0.04026 - Test loss: 0.05060
# Epoch 4847 - lr: 0.01000 - Train loss: 0.04025 - Test loss: 0.05060
# Epoch 4848 - lr: 0.01000 - Train loss: 0.04025 - Test loss: 0.05060
# Epoch 4849 - lr: 0.01000 - Train loss: 0.04025 - Test loss: 0.05060
# Epoch 4850 - lr: 0.01000 - Train loss: 0.04024 - Test loss: 0.05060
# Epoch 4851 - lr: 0.01000 - Train loss: 0.04024 - Test loss: 0.05060
# Epoch 4852 - lr: 0.01000 - Train loss: 0.04023 - Test loss: 0.05060
# Epoch 4853 - lr: 0.01000 - Train loss: 0.04023 - Test loss: 0.05060
# Epoch 4854 - lr: 0.01000 - Train loss: 0.04023 - Test loss: 0.05060
# Epoch 4855 - lr: 0.01000 - Train loss: 0.04022 - Test loss: 0.05060
# Epoch 4856 - lr: 0.01000 - Train loss: 0.04022 - Test loss: 0.05060
# Epoch 4857 - lr: 0.01000 - Train loss: 0.04021 - Test loss: 0.05060
# Epoch 4858 - lr: 0.01000 - Train loss: 0.04021 - Test loss: 0.05060
# Epoch 4859 - lr: 0.01000 - Train loss: 0.04021 - Test loss: 0.05060
# Epoch 4860 - lr: 0.01000 - Train loss: 0.04020 - Test loss: 0.05060
# Epoch 4861 - lr: 0.01000 - Train loss: 0.04020 - Test loss: 0.05060
# Epoch 4862 - lr: 0.01000 - Train loss: 0.04019 - Test loss: 0.05060
# Epoch 4863 - lr: 0.01000 - Train loss: 0.04019 - Test loss: 0.05060
# Epoch 4864 - lr: 0.01000 - Train loss: 0.04019 - Test loss: 0.05060
# Epoch 4865 - lr: 0.01000 - Train loss: 0.04018 - Test loss: 0.05060
# Epoch 4866 - lr: 0.01000 - Train loss: 0.04018 - Test loss: 0.05060
# Epoch 4867 - lr: 0.01000 - Train loss: 0.04018 - Test loss: 0.05060
# Epoch 4868 - lr: 0.01000 - Train loss: 0.04017 - Test loss: 0.05060
# Epoch 4869 - lr: 0.01000 - Train loss: 0.04017 - Test loss: 0.05059
# Epoch 4870 - lr: 0.01000 - Train loss: 0.04016 - Test loss: 0.05059
# Epoch 4871 - lr: 0.01000 - Train loss: 0.04016 - Test loss: 0.05059
# Epoch 4872 - lr: 0.01000 - Train loss: 0.04016 - Test loss: 0.05059
# Epoch 4873 - lr: 0.01000 - Train loss: 0.04015 - Test loss: 0.05059
# Epoch 4874 - lr: 0.01000 - Train loss: 0.04015 - Test loss: 0.05059
# Epoch 4875 - lr: 0.01000 - Train loss: 0.04014 - Test loss: 0.05059
# Epoch 4876 - lr: 0.01000 - Train loss: 0.04014 - Test loss: 0.05059
# Epoch 4877 - lr: 0.01000 - Train loss: 0.04014 - Test loss: 0.05059
# Epoch 4878 - lr: 0.01000 - Train loss: 0.04013 - Test loss: 0.05059
# Epoch 4879 - lr: 0.01000 - Train loss: 0.04013 - Test loss: 0.05059
# Epoch 4880 - lr: 0.01000 - Train loss: 0.04012 - Test loss: 0.05059
# Epoch 4881 - lr: 0.01000 - Train loss: 0.04012 - Test loss: 0.05059
# Epoch 4882 - lr: 0.01000 - Train loss: 0.04012 - Test loss: 0.05059
# Epoch 4883 - lr: 0.01000 - Train loss: 0.04011 - Test loss: 0.05059
# Epoch 4884 - lr: 0.01000 - Train loss: 0.04011 - Test loss: 0.05059
# Epoch 4885 - lr: 0.01000 - Train loss: 0.04010 - Test loss: 0.05059
# Epoch 4886 - lr: 0.01000 - Train loss: 0.04010 - Test loss: 0.05059
# Epoch 4887 - lr: 0.01000 - Train loss: 0.04010 - Test loss: 0.05059
# Epoch 4888 - lr: 0.01000 - Train loss: 0.04009 - Test loss: 0.05059
# Epoch 4889 - lr: 0.01000 - Train loss: 0.04009 - Test loss: 0.05059
# Epoch 4890 - lr: 0.01000 - Train loss: 0.04008 - Test loss: 0.05059
# Epoch 4891 - lr: 0.01000 - Train loss: 0.04008 - Test loss: 0.05059
# Epoch 4892 - lr: 0.01000 - Train loss: 0.04008 - Test loss: 0.05059
# Epoch 4893 - lr: 0.01000 - Train loss: 0.04007 - Test loss: 0.05059
# Epoch 4894 - lr: 0.01000 - Train loss: 0.04007 - Test loss: 0.05059
# Epoch 4895 - lr: 0.01000 - Train loss: 0.04006 - Test loss: 0.05059
# Epoch 4896 - lr: 0.01000 - Train loss: 0.04006 - Test loss: 0.05059
# Epoch 4897 - lr: 0.01000 - Train loss: 0.04006 - Test loss: 0.05059
# Epoch 4898 - lr: 0.01000 - Train loss: 0.04005 - Test loss: 0.05059
# Epoch 4899 - lr: 0.01000 - Train loss: 0.04005 - Test loss: 0.05059
# Epoch 4900 - lr: 0.01000 - Train loss: 0.04004 - Test loss: 0.05058
# Epoch 4901 - lr: 0.01000 - Train loss: 0.04004 - Test loss: 0.05058
# Epoch 4902 - lr: 0.01000 - Train loss: 0.04004 - Test loss: 0.05058
# Epoch 4903 - lr: 0.01000 - Train loss: 0.04003 - Test loss: 0.05058
# Epoch 4904 - lr: 0.01000 - Train loss: 0.04003 - Test loss: 0.05058
# Epoch 4905 - lr: 0.01000 - Train loss: 0.04002 - Test loss: 0.05058
# Epoch 4906 - lr: 0.01000 - Train loss: 0.04002 - Test loss: 0.05058
# Epoch 4907 - lr: 0.01000 - Train loss: 0.04002 - Test loss: 0.05058
# Epoch 4908 - lr: 0.01000 - Train loss: 0.04001 - Test loss: 0.05058
# Epoch 4909 - lr: 0.01000 - Train loss: 0.04001 - Test loss: 0.05058
# Epoch 4910 - lr: 0.01000 - Train loss: 0.04000 - Test loss: 0.05058
# Epoch 4911 - lr: 0.01000 - Train loss: 0.04000 - Test loss: 0.05058
# Epoch 4912 - lr: 0.01000 - Train loss: 0.04000 - Test loss: 0.05058
# Epoch 4913 - lr: 0.01000 - Train loss: 0.03999 - Test loss: 0.05058
# Epoch 4914 - lr: 0.01000 - Train loss: 0.03999 - Test loss: 0.05058
# Epoch 4915 - lr: 0.01000 - Train loss: 0.03998 - Test loss: 0.05058
# Epoch 4916 - lr: 0.01000 - Train loss: 0.03998 - Test loss: 0.05058
# Epoch 4917 - lr: 0.01000 - Train loss: 0.03998 - Test loss: 0.05058
# Epoch 4918 - lr: 0.01000 - Train loss: 0.03997 - Test loss: 0.05058
# Epoch 4919 - lr: 0.01000 - Train loss: 0.03997 - Test loss: 0.05058
# Epoch 4920 - lr: 0.01000 - Train loss: 0.03996 - Test loss: 0.05058
# Epoch 4921 - lr: 0.01000 - Train loss: 0.03996 - Test loss: 0.05058
# Epoch 4922 - lr: 0.01000 - Train loss: 0.03996 - Test loss: 0.05058
# Epoch 4923 - lr: 0.01000 - Train loss: 0.03995 - Test loss: 0.05058
# Epoch 4924 - lr: 0.01000 - Train loss: 0.03995 - Test loss: 0.05058
# Epoch 4925 - lr: 0.01000 - Train loss: 0.03995 - Test loss: 0.05058
# Epoch 4926 - lr: 0.01000 - Train loss: 0.03994 - Test loss: 0.05058
# Epoch 4927 - lr: 0.01000 - Train loss: 0.03994 - Test loss: 0.05058
# Epoch 4928 - lr: 0.01000 - Train loss: 0.03993 - Test loss: 0.05058
# Epoch 4929 - lr: 0.01000 - Train loss: 0.03993 - Test loss: 0.05057
# Epoch 4930 - lr: 0.01000 - Train loss: 0.03993 - Test loss: 0.05057
# Epoch 4931 - lr: 0.01000 - Train loss: 0.03992 - Test loss: 0.05057
# Epoch 4932 - lr: 0.01000 - Train loss: 0.03992 - Test loss: 0.05057
# Epoch 4933 - lr: 0.01000 - Train loss: 0.03991 - Test loss: 0.05057
# Epoch 4934 - lr: 0.01000 - Train loss: 0.03991 - Test loss: 0.05057
# Epoch 4935 - lr: 0.01000 - Train loss: 0.03991 - Test loss: 0.05057
# Epoch 4936 - lr: 0.01000 - Train loss: 0.03990 - Test loss: 0.05057
# Epoch 4937 - lr: 0.01000 - Train loss: 0.03990 - Test loss: 0.05057
# Epoch 4938 - lr: 0.01000 - Train loss: 0.03989 - Test loss: 0.05057
# Epoch 4939 - lr: 0.01000 - Train loss: 0.03989 - Test loss: 0.05057
# Epoch 4940 - lr: 0.01000 - Train loss: 0.03989 - Test loss: 0.05057
# Epoch 4941 - lr: 0.01000 - Train loss: 0.03988 - Test loss: 0.05057
# Epoch 4942 - lr: 0.01000 - Train loss: 0.03988 - Test loss: 0.05057
# Epoch 4943 - lr: 0.01000 - Train loss: 0.03987 - Test loss: 0.05057
# Epoch 4944 - lr: 0.01000 - Train loss: 0.03987 - Test loss: 0.05057
# Epoch 4945 - lr: 0.01000 - Train loss: 0.03986 - Test loss: 0.05057
# Epoch 4946 - lr: 0.01000 - Train loss: 0.03986 - Test loss: 0.05057
# Epoch 4947 - lr: 0.01000 - Train loss: 0.03986 - Test loss: 0.05057
# Epoch 4948 - lr: 0.01000 - Train loss: 0.03985 - Test loss: 0.05057
# Epoch 4949 - lr: 0.01000 - Train loss: 0.03985 - Test loss: 0.05057
# Epoch 4950 - lr: 0.01000 - Train loss: 0.03984 - Test loss: 0.05057
# Epoch 4951 - lr: 0.01000 - Train loss: 0.03984 - Test loss: 0.05057
# Epoch 4952 - lr: 0.01000 - Train loss: 0.03984 - Test loss: 0.05057
# Epoch 4953 - lr: 0.01000 - Train loss: 0.03983 - Test loss: 0.05057
# Epoch 4954 - lr: 0.01000 - Train loss: 0.03983 - Test loss: 0.05057
# Epoch 4955 - lr: 0.01000 - Train loss: 0.03982 - Test loss: 0.05057
# Epoch 4956 - lr: 0.01000 - Train loss: 0.03982 - Test loss: 0.05056
# Epoch 4957 - lr: 0.01000 - Train loss: 0.03982 - Test loss: 0.05056
# Epoch 4958 - lr: 0.01000 - Train loss: 0.03981 - Test loss: 0.05056
# Epoch 4959 - lr: 0.01000 - Train loss: 0.03981 - Test loss: 0.05056
# Epoch 4960 - lr: 0.01000 - Train loss: 0.03980 - Test loss: 0.05056
# Epoch 4961 - lr: 0.01000 - Train loss: 0.03980 - Test loss: 0.05056
# Epoch 4962 - lr: 0.01000 - Train loss: 0.03980 - Test loss: 0.05056
# Epoch 4963 - lr: 0.01000 - Train loss: 0.03979 - Test loss: 0.05056
# Epoch 4964 - lr: 0.01000 - Train loss: 0.03979 - Test loss: 0.05056
# Epoch 4965 - lr: 0.01000 - Train loss: 0.03978 - Test loss: 0.05056
# Epoch 4966 - lr: 0.01000 - Train loss: 0.03978 - Test loss: 0.05056
# Epoch 4967 - lr: 0.01000 - Train loss: 0.03978 - Test loss: 0.05056
# Epoch 4968 - lr: 0.01000 - Train loss: 0.03977 - Test loss: 0.05056
# Epoch 4969 - lr: 0.01000 - Train loss: 0.03977 - Test loss: 0.05056
# Epoch 4970 - lr: 0.01000 - Train loss: 0.03976 - Test loss: 0.05056
# Epoch 4971 - lr: 0.01000 - Train loss: 0.03976 - Test loss: 0.05056
# Epoch 4972 - lr: 0.01000 - Train loss: 0.03976 - Test loss: 0.05056
# Epoch 4973 - lr: 0.01000 - Train loss: 0.03975 - Test loss: 0.05056
# Epoch 4974 - lr: 0.01000 - Train loss: 0.03975 - Test loss: 0.05056
# Epoch 4975 - lr: 0.01000 - Train loss: 0.03974 - Test loss: 0.05056
# Epoch 4976 - lr: 0.01000 - Train loss: 0.03974 - Test loss: 0.05056
# Epoch 4977 - lr: 0.01000 - Train loss: 0.03974 - Test loss: 0.05056
# Epoch 4978 - lr: 0.01000 - Train loss: 0.03973 - Test loss: 0.05056
# Epoch 4979 - lr: 0.01000 - Train loss: 0.03973 - Test loss: 0.05056
# Epoch 4980 - lr: 0.01000 - Train loss: 0.03972 - Test loss: 0.05056
# Epoch 4981 - lr: 0.01000 - Train loss: 0.03972 - Test loss: 0.05055
# Epoch 4982 - lr: 0.01000 - Train loss: 0.03972 - Test loss: 0.05055
# Epoch 4983 - lr: 0.01000 - Train loss: 0.03971 - Test loss: 0.05055
# Epoch 4984 - lr: 0.01000 - Train loss: 0.03971 - Test loss: 0.05055
# Epoch 4985 - lr: 0.01000 - Train loss: 0.03970 - Test loss: 0.05055
# Epoch 4986 - lr: 0.01000 - Train loss: 0.03970 - Test loss: 0.05055
# Epoch 4987 - lr: 0.01000 - Train loss: 0.03970 - Test loss: 0.05055
# Epoch 4988 - lr: 0.01000 - Train loss: 0.03969 - Test loss: 0.05055
# Epoch 4989 - lr: 0.01000 - Train loss: 0.03969 - Test loss: 0.05055
# Epoch 4990 - lr: 0.01000 - Train loss: 0.03968 - Test loss: 0.05055
# Epoch 4991 - lr: 0.01000 - Train loss: 0.03968 - Test loss: 0.05055
# Epoch 4992 - lr: 0.01000 - Train loss: 0.03968 - Test loss: 0.05055
# Epoch 4993 - lr: 0.01000 - Train loss: 0.03967 - Test loss: 0.05055
# Epoch 4994 - lr: 0.01000 - Train loss: 0.03967 - Test loss: 0.05055
# Epoch 4995 - lr: 0.01000 - Train loss: 0.03966 - Test loss: 0.05055
# Epoch 4996 - lr: 0.01000 - Train loss: 0.03966 - Test loss: 0.05055
# Epoch 4997 - lr: 0.01000 - Train loss: 0.03966 - Test loss: 0.05055
# Epoch 4998 - lr: 0.01000 - Train loss: 0.03965 - Test loss: 0.05055
# Epoch 4999 - lr: 0.01000 - Train loss: 0.03965 - Test loss: 0.05055
# Epoch 5000 - lr: 0.01000 - Train loss: 0.03964 - Test loss: 0.05055

# %% [markdown]
# Plot train and test loss during training

# %%
plt.close('all')
plt.figure(figsize=(12,8))
plt.semilogy(train_loss_log, label='Train loss')
plt.semilogy(test_loss_log, label='Test loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Plot weights after training

# %%
net.plot_weights()
# Out:
# C:\Users\giuse\AppData\Local\Temp\ipykernel_15656\3783862196.py:121: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
### FORWARD PASS (after training)
net_output = np.array([net.forward(x) for x in x_highres])

### Plot
plt.close('all')
plt.figure(figsize=(12,8))
x_highres = np.linspace(0,1,1000)
plt.plot(x_highres, poly_model(x_highres, beta_true), color='b', ls='--', label='True data model')
plt.plot(x_train, y_train, color='r', ls='', marker='.', label='Train data points')
plt.plot(x_highres, net_output, color='g', ls='--', label='Network output (trained weights)')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Now the output is better, but it can still be improved by a large margin. Try to improve it by changing the network structure and the training hyper-parameters, but remember: **THIS MUST BE DONE ON A VALIDATION SET!**

# %% [markdown]
# # Analyze activations

# %% [markdown]
# By enabling the *additional_out* parameter of the *forward* method, we can see the activations of the last layer for a given input. Let's try with 3 different input values: $x=0.1$, $x=0.9$ and $x=2.5$.

# %%
x1 = 0.1
y1, z1 = net.forward(x1, additional_out=True)
x2 = 0.9
y2, z2 = net.forward(x2, additional_out=True)
x3 = 2.5
y3, z3 = net.forward(x3, additional_out=True)

fig, axs = plt.subplots(3, 1, figsize=(12,6))
axs[0].stem(z1)
axs[0].set_title('Last layer activations for input x=%.2f' % x1)
axs[1].stem(z2)
axs[1].set_title('Last layer activations for input x=%.2f' % x2)
axs[2].stem(z3)
axs[2].set_title('Last layer activations for input x=%.2f' % x3)
plt.tight_layout()
plt.show()

# %% [markdown]
# As you may have noticed, some neurons are contributing much more than the others. Maybe the number of neurons is too high? Try to make some changes and see what happens.
#
# In the last case the input is $x=2.5$, far away from the training space $[0,1]$. The behavior of the network seems to be quite confused, maybe it is not generalizing very well, try to do some tests to check this hypothesis.
